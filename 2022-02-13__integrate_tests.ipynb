# %% [markdown]
# # Testing the Space-time Integral Operator

# %% [markdown]
# What _should_ the space-time integral operator look like? One adds up differential elements of a function. Which ones? All 16. This idea mirrors the one I have used for the derivative: multiply a differential by the function and do all the possibilities space-time algebra allows:
#
# $$\int ({\partial t}, \partial \vec{R})(f, \vec{F}) = \int (\partial t f - \partial R \cdot F, \partial t \vec{F} + \partial \vec{R} f + \partial \vec{R} \times \vec{F}) \;.$$
#
# The goal is to sse if this function is consistent with what happens in complex analysis.
#
# Load the libraries.

# %%
# %%capture
# %matplotlib inline
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import math
import unittest

# To get equations the look like, well, equations, use the following.
from sympy.interactive import printing
printing.init_printing(use_latex=True)
from IPython.display import display

# Tools for manipulating quaternions.
from Qs import *

from IPython.core.display import display, HTML, Math, Latex
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# The approach is to use _the same structure_ for the integral as the was used for the derivative of a space-time number function. Here is the code for when the derivatives get taken:
#
# ```python
#     for sign, var in enumerate(vars):
#         if var in these_vars:
#             the_16.append(sp.diff(D_signs[sign] * q_1.t, var))
#             the_16.append(sp.diff(D_signs[sign] * q_1.x, var))
#             the_16.append(sp.diff(D_signs[sign] * q_1.y, var))
#             the_16.append(sp.diff(D_signs[sign] * q_1.z, var))
# ```
#
# There are 2 changes. First, sp.diff() goes to sp.integrate(). Second, the integrate() function has optional limit values. Other than those two changes, the code is the same.

# %%
def Iq(q_1: Q, vars: List[sp.Symbol], these_vars: List[sp.Symbol] = None, conj: bool = False, conj_type: int=0,
       reverse: bool=False, limit: List = None, limits: List = None) -> Q:
    """
    Calculate the space-time number integral composed of 16 terms. The conjugation applies to the differential operator.
    The reverse flag will flip the cross product terms.

    Args:
        q_1         A symbolic expression that returns a space-time number expression.
        vars        A complete list of what 4 symbols are being used.
        these_vars  An optional (possibly shorter) list of symbols to use to take a derivative.
        conj        If one wants to take a conjugate of the differential operator, set this option.
        conj_type   An integer for which term is positive, 0 the default for the standard conjugate.
                    The first, second, and third conjugates flip the other three, keeping the first, 
                    second, and third term positive
        limit       One lower/upper limit list applied to all integrals
        limits      Four lower/upper limit lists applied to each integral
    
    Return:
        Q     The space-time integral
    """
    
    if conj and conj_type and reverse:
        end_q_type = f"{q_1.q_type}I*{conj_type}"
    elif conj and conj_type:
         end_q_type = f"I*{conj_type}{q_1.q_type}"
    elif conj and reverse:
        end_q_type = f"{q_1.q_type}I*"
    elif conj:
        end_q_type = f"I*{q_1.q_type}"
    elif reverse:
        end_q_type = f"{q_1.q_type}I"
    else:
        end_q_type = f"I{q_1.q_type}"
    
    # Check for errors.
    if len(vars) != 4:
        print("Oops: needs to be given 4 symbols. Try again.")
        return q0()
    
    if not q_1.is_symbolic():
        print("Oops, the function needs to be symbolic.")
        return q0()
        
    if these_vars is None:
        these_vars = vars
        
    # Use the_D_signs to apply different conjugates to the differentials.
    D_signs = [1, 1, 1, 1]
    
    if conj:
        if conj_type == 0:
            D_signs = [1, -1, -1, -1]
        if conj_type == 1:
            D_signs = [-1, 1, -1, -1]
        if conj_type == 2:
            D_signs = [-1, -1, 1, -1]
        if conj_type == 3:
            D_signs = [-1, -1, -1, 1]
    
    the_16 = []
    
    for sign, var in enumerate(vars):
        if var in these_vars:
            if limits is None:
                the_16.append(sp.integrate(D_signs[sign] * q_1.t, var))
                the_16.append(sp.integrate(D_signs[sign] * q_1.x, var))
                the_16.append(sp.integrate(D_signs[sign] * q_1.y, var))
                the_16.append(sp.integrate(D_signs[sign] * q_1.z, var))
            else:
                if len(limits) != 2:
                    print("Oops, need exactly a list of 2 for limits.")
                    return 0
                    
                the_16.append(sp.integrate(D_signs[sign] * q_1.t, (var, limits[0], limits[1])))
                the_16.append(sp.integrate(D_signs[sign] * q_1.x, (var, limits[0], limits[1])))
                the_16.append(sp.integrate(D_signs[sign] * q_1.y, (var, limits[0], limits[1])))
                the_16.append(sp.integrate(D_signs[sign] * q_1.z, (var, limits[0], limits[1])))
                
        else:
            for _ in range(4):
                the_16.append(0)

    flip = -1 if reverse else 1

    first_term =  the_16[0] - (the_16[5] + the_16[10] + the_16[15])
    second_term = the_16[1] + the_16[4] + flip * the_16[11] - flip * the_16[14]
    third_term =  the_16[2] + the_16[8] + flip * the_16[13] - flip * the_16[7]
    forth_term =  the_16[3] + the_16[12] + flip * the_16[6] - flip * the_16[9]
    
    return Q([first_term.simplify(), second_term.simplify(), third_term.simplify(), forth_term.simplify()], q_type=end_q_type)

# %%
def Iqs(q_1: Qs, vars: List[sp.Symbol], these_vars: List[sp.Symbol] = None, conj: bool = False, conj_type: int=0,
        reverse: bool=False, limit: List = None, limits: List = None) -> Qs:
    """
    Calculate the space-time number interval composed of 16 terms. The conjugation applies to the integral operator. The reverse flag will flip the cross product terms.
    
    Args:
        q_1         Symbolic expressions that returns a space-time number expression in a space-time number series.
        vars        A complete list of what 4 symbols are being used.
        these_vars  An optional (possibly shorter) list of symbols to use to take a derivative.
        conj        If one wants to take a conjugate of the differential operator, set this option.
        conj_type   An integer for which term is positive, 0 the default for the standard conjugate.
                    The first, second, and third conjugates flip the other three, keeping the first, 
                    second, and third term positive
        limit       One lower/upper limit list applied to all integrals
        limits      Four lower/upper limit lists applied to each integral
        
    Return:
        Q     The space-time integral
    """
    
    results = [Iq(q, vars, these_vars, conj, conj_type, reverse) for q in q_1.qs]
    
    return Qs(results, qs_type=q_1.qs_type, rows=q_1.rows, columns=q_1.columns)

# %% [markdown]
# Test that the function works on a real-valued cubic function:

# %%
t, x, y, z = sp.symbols("t x y z")
q_t = Q([t,0, 0, 0])
q_t_3 = product(product(q_t, q_t), q_t)
q_t_3.print_state("q_t³")
I_t_3_dt = Iq(q_t_3, [t, x, y, z], [t])
I_t_3_dt.print_state("I_t³_dt")
# Out:
# q_t³
# (t**3, 0, 0, 0)
#
# I_t³_dt
# (t**4/4, 0, 0, 0)

# %% [markdown]
# That looks right. Check that the fundamental rule of calculus works:

# %%
I_D_t_3_dt = Iq(Dq(q_t_3, [t, x, y, z], [t]), [t, x, y, z], [t])
I_D_t_3_dt.print_state("I_D_t³_dt")
# Out:
# I_D_t³_dt
# (t**3, 0, 0, 0)

# %% [markdown]
# It turns out not to matter if one does the derivative first or the integral.

# %%
D_I_t_3_dt = Dq(Iq(q_t_3, [t, x, y, z], [t]), [t, x, y, z], [t])
D_I_t_3_dt.print_state("D_I_t³_dt")
# Out:
# D_I_t³_dt
# (t**3, 0, 0, 0)

# %% [markdown]
# Now a complex-valued cubic:

# %%
q_tx = Q([t, x, 0, 0])
q_tx_3 = product(product(q_tx, q_tx), q_tx)
q_tx_3.expand().display("q_tx³")
I_tx_3_dt_dx = Iq(q_tx_3, [t, x, y, z], [t, x])
I_tx_3_dt_dx.display("I_tx³_dt dx")
# Out:
# q_tx³
#  3        2
# t  - 3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0
# I_tx³_dt dx
#  4              4
# t       2  2   x
# ── - 3⋅t ⋅x  + ──
# 4              4
#       ⎛ 2    2⎞
# 2⋅t⋅x⋅⎝t  - x ⎠
# 0
# 0

# %% [markdown]
# Is there a fundamental theorem for complex calculus?

# %%
I_D_tx_3_dt_dx = Iq(Dq(q_tx_3, [t, x, y, z], [t, x]), [t, x, y, z], [t, x])
I_D_tx_3_dt_dx.expand().display("I_D_tx³_dt_dx")
# Out:
# I_D_tx³_dt_dx
# 0
# 0
# 0
# 0

# %% [markdown]
# Oops, the cubic function is analytic in $q$, so after the derivative, the result is zero. Try the reverse order:

# %%
D_I_tx_3_dt_dx = Dq(Iq(q_tx_3, [t, x, y, z], [t, x]), [t, x, y, z], [t, x])
D_I_tx_3_dt_dx.expand().display("D_I_tx³_dt_dx")
# Out:
# D_I_tx³_dt_dx
#   3
# -t
#   3
# -x
# 0
# 0

# %% [markdown]
# Although this is non-zero, the original function was not recovered.
#
# The **fundamental theorem of calculus** sounds too fundamental to not understand. We must know how to recover an original analytic function after operating on it with a differential operator and then an integral.
#
# The Cauchy-Riemann equations has two different relations. One is the real/real versus imaginary/imaginary. The other is imaginary/real versus real/imaginary. There may be a minus sign tossed in here or there as need be.
#
# First see if the real part of the function can be recovered using both real/real and imaginary/imaginary derivatives and integrals.

# %%
I_D_tx_3_dt__dt = Iq(Dq(q_tx_3, [t, x, y, z], [t]), [t, x, y, z], [t])
I_D_tx_3_dt__dt.expand().display("I_D_tx³_dt__dt")
# Out:
# I_D_tx³_dt__dt
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0

# %% [markdown]
# Nice, the real term is the real term of the original cubic function. No partial credit is given for the imaginary term. There are costs to using only the reals. Here is what was done using symbols:
#
# $$(f, 0, 0, 0) = \rm{Re}\left(\int d(t, 0, 0, 0) \frac{\partial(f, F_x, 0, 0)}{\partial (t, 0, 0, 0)} \right)$$
#
# This is one way to recover the real part of an analytic function.

# %% [markdown]
# Now try only the imaginaries:

# %%
I_D_tx_3_dx__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [x])
I_D_tx_3_dx__dx.expand().display("I_D_tx³_dx__dx")
# Out:
# I_D_tx³_dx__dx
#      2
# 3⋅t⋅x
#      2      3
# - 3⋅t ⋅x + x
# 0
# 0

# %% [markdown]
# The imaginary is off by a sign. Use a conjugate operator:

# %%
I_D_tx_3_dx_c__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [x])
I_D_tx_3_dx_c__dx.expand().display("I_D_tx³_dx*__dx")
# Out:
# I_D_tx³_dx*__dx
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %% [markdown]
# This is a little unsatisfying since we are just "grabbing needed parts" instead of getting one expression that recovers the original function. I tried reversing the integral and derivative, tossing in a conjugate, and got this clean result.

# %%
D_I_tx_3_dx_c__dx = Dq(Iq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [x])
D_I_tx_3_dx_c__dx.expand().display("D_I_tx³_dx*__dx")
# Out:
# D_I_tx³_dx*__dx
#  3        2
# t  - 3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %% [markdown]
# Bingo, bingo for recovering the original imaginary term. Let's find the derivative/integral using just time.

# %%
D_I_tx_3_dt_c__dt = Dq(Iq(q_tx_3, [t, x, y, z], [t]), [t, x, y, z], [t])
D_I_tx_3_dt_c__dt.expand().display("D_I_tx³_dt__dt")
# Out:
# D_I_tx³_dt__dt
#  3        2
# t  - 3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %% [markdown]
# Either of these work to recover the full function:
#
# $$(f, F_x, 0, 0) = \frac{\partial}{\partial (t, 0, 0, 0)} \int d(t, 0, 0, 0)(f, F_x, 0, 0)$$
#
# $$(f, F_x, 0, 0) = \frac{\partial}{\partial (0, x, 0, 0)} \int d(0, x, 0, 0)^*(f, F_x, 0, 0)$$
#
# There should be another path, using a mixture of real/imaginary and imaginary/real derivatives and integrals.

# %%
I_D_tx_3_dx_c__dt = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [t])
I_D_tx_3_dx_c__dt.expand().display("I_D_tx³_dx*__dt")
# Out:
# I_D_tx³_dx*__dt
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0

# %%
I_D_tx_3_dt__dx = Iq(Dq(q_tx_3, [t, x, y, z], [t]), [t, x, y, z], [x])
I_D_tx_3_dt__dx.expand().display("I_D_tx³_dt__dx")
# Out:
# I_D_tx³_dt__dx
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %% [markdown]
# See if the trick of reversing order works to get the entire function.

# %%
D_I_tx_3_dx__dt = Dq(Iq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [t])
D_I_tx_3_dx__dt.expand().display("D_I_tx³_dx__dt")
# Out:
# D_I_tx³_dx__dt
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %% [markdown]
# This time it does not.
#
# The full function can be recovered like so:
#
# $$(f, F_x, 0, 0) = \rm{Re} \left( \int d(0, x, 0, 0)^* \frac{\partial(f, F_x, 0, 0)}{(t, 0, 0, 0)} \right)+ \rm{Im} \left(\int d(t, 0, 0, 0) \frac{\partial(f, F_x, 0, 0)}{(0, x, 0, 0)} \right)$$

# %%
I_D_tx_3_dx__dt = Iq(Dq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [t])
I_D_tx_3_dx__dt.expand().display("I_D_tx³_dx__dt")
I_D_tx_3_dt__dx = Iq(Dq(q_tx_3, [t, x, y, z], [t]), [t, x, y, z], [x])
I_D_tx_3_dt__dx.expand().display("I_D_tx³_dt__dx")
selective_dif = dif(vector_q(I_D_tx_3_dt__dx), scalar_q(I_D_tx_3_dx__dt))
selective_dif.display("selective dif")
# Out:
# I_D_tx³_dx__dt
#    3        2
# - t  + 3⋅t⋅x
#     2
# -3⋅t ⋅x
# 0
# 0
# I_D_tx³_dt__dx
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0
# selective dif
#  3        2
# t  - 3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0

# %%
I_D_tx_3_c_dx__dt = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [t])
I_D_tx_3_c_dx__dt.expand().display("I_D_tx³_dx*__dt")
I_D_tx_3_c_dx__dt = Iq(Dq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [t], conj=True)
I_D_tx_3_c_dx__dt.expand().display("I_D_tx³_dx*__dt*")
I_D_tx_3_c_dx__dt = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [t], conj=True)
I_D_tx_3_c_dx__dt.expand().display("I_D_tx³_dx*__dt*")
# Out:
# I_D_tx³_dx*__dt
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0
# I_D_tx³_dx*__dt*
#    3        2
# - t  + 3⋅t⋅x
#     2
# -3⋅t ⋅x
# 0
# 0
# I_D_tx³_dx*__dt*
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0

# %%
I_D_tx_3_dt__dt = Iq(Dq(q_tx_3, [t, x, y, z], [t], conj=True), [t, x, y, z], [t])
I_D_tx_3_dt__dt.expand().display("I_D_tx³_dt__dt")
I_D_tx_3_c_dt__dt = Iq(Dq(q_tx_3, [t, x, y, z], [t], conj=True), [t, x, y, z], [t])
I_D_tx_3_c_dt__dt.expand().display("I_D_tx³_dt*__dt")
I_D_tx_3_c_dt__dt = Iq(Dq(q_tx_3, [t, x, y, z], [t]), [t, x, y, z], [t], conj=True)
I_D_tx_3_c_dt__dt.expand().display("I_D_tx³_dt*__dt*")
I_D_tx_3_c_dt__dt = Iq(Dq(q_tx_3, [t, x, y, z], [t], conj=True), [t, x, y, z], [t], conj=True)
I_D_tx_3_c_dt__dt.expand().display("I_D_tx³_dt*__dt*")
I_D_tx_3_dx__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [x])
I_D_tx_3_dx__dx.expand().display("I_D_tx³_dx__dx")
I_D_tx_3_c_dx__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [x])
I_D_tx_3_c_dx__dx.expand().display("I_D_tx³_dx*__dx")
I_D_tx_3_c_dx__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x]), [t, x, y, z], [x], conj=True)
I_D_tx_3_c_dx__dx.expand().display("I_D_tx³_dx*__dx*")
I_D_tx_3_c_dx__dx = Iq(Dq(q_tx_3, [t, x, y, z], [x], conj=True), [t, x, y, z], [x], conj=True)
I_D_tx_3_c_dx__dx.expand().display("I_D_tx³_dx*__dx*")
# Out:
# I_D_tx³_dt__dt
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0
# I_D_tx³_dt*__dt
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0
# I_D_tx³_dt*__dt*
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0
# I_D_tx³_dt*__dt*
#  3        2
# t  - 3⋅t⋅x
#    2
# 3⋅t ⋅x
# 0
# 0
# I_D_tx³_dx__dx
#      2
# 3⋅t⋅x
#      2      3
# - 3⋅t ⋅x + x
# 0
# 0
# I_D_tx³_dx*__dx
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0
# I_D_tx³_dx*__dx*
#       2
# -3⋅t⋅x
#    2      3
# 3⋅t ⋅x - x
# 0
# 0
# I_D_tx³_dx*__dx*
#      2
# 3⋅t⋅x
#      2      3
# - 3⋅t ⋅x + x
# 0
# 0

# %% [raw]
# q_tx_c = conj(Q([t, x, 0, 0]))
# q_tx_c_3 = product(product(q_tx_c, q_tx_c), q_tx_c)
# q_tx_c_3.display("q_tx*³")
# I_tx_c_3_dt = Iq(q_tx_c_3, [t, x, y, z], [t, x])
# I_tx_3_dt.display("I_tx*³_dt")

# %%
q_txyz = Q([t, x, y, z])
q_txyz_3 = product(product(q_txyz, q_txyz), q_txyz).expand()
q_txyz_3.display("q_txyz³")
I_txyz_3_dt = Iq(q_txyz_3, [t, x, y, z], [t]).expand()
I_txyz_3_dt.display("I_tx³_dt")
I_txyz_3_dx = Iq(q_txyz_3, [t, x, y, z], [x]).expand()
I_txyz_3_dx.display("I_tx³_dx")
I_txyz_3_dtdxdydz = Iq(q_txyz_3, [t, x, y, z], [t, x, y, z]).expand()
I_txyz_3_dtdxdydz.display("I_tx³_dt_dx_dy_dz")
# Out:
# q_txyz³
#  3        2        2        2
# t  - 3⋅t⋅x  - 3⋅t⋅y  - 3⋅t⋅z
#    2      3      2      2
# 3⋅t ⋅x - x  - x⋅y  - x⋅z
#    2      2      3      2
# 3⋅t ⋅y - x ⋅y - y  - y⋅z
#    2      2      2      3
# 3⋅t ⋅z - x ⋅z - y ⋅z - z
# I_tx³_dt
#  4      2  2      2  2      2  2
# t    3⋅t ⋅x    3⋅t ⋅y    3⋅t ⋅z
# ── - ─────── - ─────── - ───────
# 4       2         2         2
#  3        3        2        2
# t ⋅x - t⋅x  - t⋅x⋅y  - t⋅x⋅z
#  3        2        3        2
# t ⋅y - t⋅x ⋅y - t⋅y  - t⋅y⋅z
#  3        2        2        3
# t ⋅z - t⋅x ⋅z - t⋅y ⋅z - t⋅z
# I_tx³_dx
#      2  2    4    2  2    2  2
#   3⋅t ⋅x    x    x ⋅y    x ⋅z
# - ─────── + ── + ───── + ─────
#      2      4      2       2
#  3        3          2          2
# t ⋅x - t⋅x  - 3⋅t⋅x⋅y  - 3⋅t⋅x⋅z
#               3
#      2       x ⋅z      2        3
# - 3⋅t ⋅x⋅z + ──── + x⋅y ⋅z + x⋅z
#               3
#             3
#    2       x ⋅y      3        2
# 3⋅t ⋅x⋅y - ──── - x⋅y  - x⋅y⋅z
#             3
# I_tx³_dt_dx_dy_dz
#  4                                  4                    4            4
# t       2  2      2  2      2  2   x     2  2    2  2   y     2  2   z
# ── - 3⋅t ⋅x  - 3⋅t ⋅y  - 3⋅t ⋅z  + ── + x ⋅y  + x ⋅z  + ── + y ⋅z  + ──
# 4                                  4                    4            4
#                                            3          3
#    3          3          2          2   2⋅y ⋅z   2⋅y⋅z
# 2⋅t ⋅x - 2⋅t⋅x  - 4⋅t⋅x⋅y  - 4⋅t⋅x⋅z  + ────── - ──────
#                                           3        3
#                                            3          3
#    3          2          3          2   2⋅x ⋅z   2⋅x⋅z
# 2⋅t ⋅y - 4⋅t⋅x ⋅y - 2⋅t⋅y  - 4⋅t⋅y⋅z  - ────── + ──────
#                                           3        3
#                                            3          3
#    3          2          2          3   2⋅x ⋅y   2⋅x⋅y
# 2⋅t ⋅z - 4⋅t⋅x ⋅z - 4⋅t⋅y ⋅z - 2⋅t⋅z  + ────── - ──────
#                                           3        3

# %%
q_txyz = Q([t, x, y, z])
q_txyz_3 = product(product(q_txyz, q_txyz), q_txyz).expand()
q_txyz_3.display("q_txyz³")
D_txyz_3_dt = Dq(q_txyz_3, [t, x, y, z], [t]).expand()
D_txyz_3_dt.display("D_txyz³_dt")
D_txyz_3_dx = Dq(q_txyz_3, [t, x, y, z], [x]).expand()
D_txyz_3_dx.display("D_txyz³_dx")
D_txyz_3_dy = Dq(q_txyz_3, [t, x, y, z], [y]).expand()
D_txyz_3_dy.display("D_txyz³_dy")
D_txyz_3_dz = Dq(q_txyz_3, [t, x, y, z], [z]).expand()
D_txyz_3_dz.display("D_txyz³_dz")
D_txyz_3_dtdxdydz = Dq(q_txyz_3, [t, x, y, z]).expand()
D_txyz_3_dtdxdydz.display("D_txyx³_dtdxdydz")
# Out:
# q_txyz³
#  3        2        2        2
# t  - 3⋅t⋅x  - 3⋅t⋅y  - 3⋅t⋅z
#    2      3      2      2
# 3⋅t ⋅x - x  - x⋅y  - x⋅z
#    2      2      3      2
# 3⋅t ⋅y - x ⋅y - y  - y⋅z
#    2      2      2      3
# 3⋅t ⋅z - x ⋅z - y ⋅z - z
# D_txyz³_dt
#    2      2      2      2
# 3⋅t  - 3⋅x  - 3⋅y  - 3⋅z
# 6⋅t⋅x
# 6⋅t⋅y
# 6⋅t⋅z
# D_txyz³_dx
#      2      2    2    2
# - 3⋅t  + 3⋅x  + y  + z
# -6⋅t⋅x
# 2⋅x⋅z
# -2⋅x⋅y
# D_txyz³_dy
#      2    2      2    2
# - 3⋅t  + x  + 3⋅y  + z
# -2⋅y⋅z
# -6⋅t⋅y
# 2⋅x⋅y
# D_txyz³_dz
#      2    2    2      2
# - 3⋅t  + x  + y  + 3⋅z
# 2⋅y⋅z
# -2⋅x⋅z
# -6⋅t⋅z
# D_txyx³_dtdxdydz
#      2      2      2      2
# - 6⋅t  + 2⋅x  + 2⋅y  + 2⋅z
# 0
# 0
# 0

# %% [markdown]
# Now there are mixed terms, various products of $x$, $y$, and $z$. Cubic functions remain analytic for _complex_ values:

# %%
q_tx = Q([t, x, 0, 0])
q_tx_3 = product(product(q_tx, q_tx), q_tx)
q_tx_3.display("q_tx³")
D_tx_3_dt = Dq(q_tx_3, [t, x, y, z], [t])
D_tx_3_dt.display("D_txyz³_dt")
D_tx_3_dx = Dq(q_tx_3, [t, x, y, z], [x])
D_tx_3_dx.display("D_txyz³_dx")
D_tx_3_dy = Dq(q_tx_3, [t, x, y, z], [y])
D_tx_3_dy.print_state("D_txyz³_dy")
D_tx_3_dz = Dq(q_tx_3, [t, x, y, z], [z])
D_tx_3_dz.print_state("D_tx³_dz")
D_tx_3_dtdx = Dq(q_tx_3, [t, x, y, z], [t, x])
D_tx_3_dtdx.print_state("D_tx³_dtdx")
# Out:
# q_tx³
#        2     ⎛ 2    2⎞
# - 2⋅t⋅x  + t⋅⎝t  - x ⎠
#    2       ⎛ 2    2⎞
# 2⋅t ⋅x + x⋅⎝t  - x ⎠
# 0
# 0
# D_txyz³_dt
#    2      2
# 3⋅t  - 3⋅x
# 6⋅t⋅x
# 0
# 0
# D_txyz³_dx
#      2      2
# - 3⋅t  + 3⋅x
# -6⋅t⋅x
# 0
# 0
# D_txyz³_dy
# (0, 0, 0, 0)
#
# D_tx³_dz
# (0, 0, 0, 0)
#
# D_tx³_dtdx
# (0, 0, 0, 0)

# %% [markdown]
# This remains a consistent theme: everything done in complex analysis is exactly mirrored with complex-valued space-time numbers. When more imaginaries are used, then the divergence of what are complex-valued analytic functions becomes non-zero. When the divergence is zero, one often says it is conservative, as in no energy is used for the pattern seen. Under that interpretation, a move from a complex analytic function to a full space-time number function involves the input or production of energy.

# %% [markdown]
# # The Tests

# %%
class TestDq(unittest.TestCase):
    """Test states."""
    
    def test_Dq_derivative(self):
        T, X, Y, Z = sp.symbols("T X Y Z")
        TXYZ = [T, X, Y, Z]
            
        self.assertTrue(equal(Dq(q1(), TXYZ), q0()))
        self.assertTrue(equal(Dq(Q([T, X, Y, Z]), [T]), q0()))
        
        q_TX = Q([T, X, 0, 0])
        q_TX_3 = product(product(q_TX, q_TX), q_TX)
        D_q_TX_3 = Dq(q_TX, TXYZ)
        self.assertTrue(D_q_TX_3.t == 0)
        self.assertTrue(D_q_TX_3.x == 0)
        self.assertTrue(D_q_TX_3.y == 0)
        self.assertTrue(D_q_TX_3.z == 0)
        
        q_TXYZ = Q(TXYZ)
        q_TXYZ_3 = product(product(q_TXYZ, q_TXYZ), q_TXYZ)
        D_q_TXYZ_3 = Dq(q_TXYZ_3, TXYZ)
        self.assertTrue(D_q_TXYZ_3.t == -6*T**2 + 2*X**2 + 2*Y**2 + 2*Z**2)
        self.assertTrue(D_q_TXYZ_3.x ==  0)
        self.assertTrue(D_q_TXYZ_3.y ==  0)
        self.assertTrue(D_q_TXYZ_3.z ==  0)
        
    def test_Dqs_derivative(self):
        T, X, Y, Z = sp.symbols("T X Y Z")
        TXYZ = [T, X, Y, Z]
            
        self.assertTrue(equals(Dqs(Qs([q1()]), TXYZ), q0s()))
        self.assertTrue(equals(Dqs(Qs([Q([T, X, Y, Z])]), [T]), q0s()))
        
        q_TX = Q([T, X, 0, 0])
        q_TX_3 = product(product(q_TX, q_TX), q_TX)
        
        q_TXYZ = Q(TXYZ)
        q_TXYZ_3 = product(product(q_TXYZ, q_TXYZ), q_TXYZ)
        
        qs_TX_3_TXYZ_3 = Qs([q_TX_3, q_TXYZ_3])
        
        D_q_TX_3_TXYZ_3 = Dqs(qs_TX_3_TXYZ_3, TXYZ)
        
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[0].t == 0)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[0].x == 0)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[0].y == 0)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[0].z == 0)
        
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[1].t == -6*T**2 + 2*X**2 + 2*Y**2 + 2*Z**2)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[1].x ==  0)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[1].y ==  0)
        self.assertTrue(D_q_TX_3_TXYZ_3.qs[1].z ==  0)
        
suite = unittest.TestLoader().loadTestsFromModule(TestDq())
unittest.TextTestRunner().run(suite);
# Out:
# ..
# Oops, the function needs to be symbolic.
# Oops: needs to be given 4 symbols. Try again.
# Oops, the function needs to be symbolic.
# Oops: needs to be given 4 symbols. Try again.
# ----------------------------------------------------------------------
# Ran 2 tests in 0.147s
#
# OK

# %%
q_txyz = Q([t, x, y, z])
q_txyz_3 = product(product(q_txyz, q_txyz), q_txyz).expand()
q_txyz_3.display()
# Out:
#  3        2        2        2
# t  - 3⋅t⋅x  - 3⋅t⋅y  - 3⋅t⋅z
#    2      3      2      2
# 3⋅t ⋅x - x  - x⋅y  - x⋅z
#    2      2      3      2
# 3⋅t ⋅y - x ⋅y - y  - y⋅z
#    2      2      2      3
# 3⋅t ⋅z - x ⋅z - y ⋅z - z

# %%
conjugates = [[False, 0, ""], [True, 0, "*"], [True, 1, "*1"], [True, 2, "*2"]]
i_conj = ["*", "*1", "*2"]
all_t = set()
all_t_tags = {}
all_x = set()
all_x_tags = {}
all_y = set()
all_y_tags = {}
all_z = set()
all_z_tags = {}

for I_conjugate in conjugates:
    for D_conjugate in conjugates:
        ID_q=Iq(Dq(q_txyz_3, [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
        tag = f"I{I_conjugate[2]} D{D_conjugate[2]} F"
        print(tag)
        display(ID_q.t)
        all_t.add(ID_q.t)
        key = str(ID_q.t)
        all_t_tags[key] = tag
        all_x.add(ID_q.x)
        key = str(ID_q.x)
        all_x_tags[key] = tag
        all_y.add(ID_q.y)
        key = str(ID_q.y)
        all_y_tags[key] = tag
        all_z.add(ID_q.z)
        key = str(ID_q.z)
        all_z_tags[key] = tag
        
        for i in range(3):
            ID_q=Iq(Dq(conj(q_txyz_3, conj_type=i), [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
            tag = f"I{I_conjugate[2]} D{D_conjugate[2]} F{i_conj[i]}"
            print(tag)
            display(ID_q.t)
            all_t.add(ID_q.t)
            key = str(ID_q.t)
            all_t_tags[key] = tag
            all_x.add(ID_q.x)
            key = str(ID_q.x)
            all_x_tags[key] = tag
            all_y.add(ID_q.y)
            key = str(ID_q.y)
            all_y_tags[key] = tag
            all_z.add(ID_q.z)
            key = str(ID_q.z)
            all_z_tags[key] = tag

for I_conjugate in conjugates:
    for D_conjugate in conjugates:
        ID_q=Iq(Dq(q_txyz_3, [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1], reverse=True), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
        tag = f"Rev I{I_conjugate[2]} D{D_conjugate[2]} F"
        print(tag)
        display(ID_q.t)
        all_t.add(ID_q.t)
        key = str(ID_q.t)
        all_t_tags[key] = tag
        all_x.add(ID_q.x)
        key = str(ID_q.x)
        all_x_tags[key] = tag
        all_y.add(ID_q.y)
        key = str(ID_q.y)
        all_y_tags[key] = tag
        all_z.add(ID_q.z)
        key = str(ID_q.z)
        all_z_tags[key] = tag
        
        for i in range(3):
            ID_q=Iq(Dq(conj(q_txyz_3, conj_type=i), [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1], reverse=True), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
            tag = f"Rev I{I_conjugate[2]} D{D_conjugate[2]} F{i_conj[i]}"
            print(tag)
            display(ID_q.t)
            all_t.add(ID_q.t)
            key = str(ID_q.t)
            all_t_tags[key] = tag
            all_x.add(ID_q.x)
            key = str(ID_q.x)
            all_x_tags[key] = tag
            all_y.add(ID_q.y)
            key = str(ID_q.y)
            all_y_tags[key] = tag
            all_z.add(ID_q.z)
            key = str(ID_q.z)
            all_z_tags[key] = tag

for I_conjugate in conjugates:
    for D_conjugate in conjugates:
        DI_q=Dq(Iq(q_txyz_3, [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
        tag = f"D{D_conjugate[2]} I{I_conjugate[2]} F"
        print(tag)
        display(DI_q.t)
        all_t.add(DI_q.t)
        key = str(DI_q.t)
        all_t_tags[key] = tag
        all_x.add(DI_q.x)
        key = str(DI_q.x)
        all_x_tags[key] = tag
        all_y.add(DI_q.y)
        key = str(DI_q.y)
        all_y_tags[key] = tag
        all_z.add(DI_q.z)
        key = str(DI_q.z)
        all_z_tags[key] = tag
        
        for i in range(3):
            DI_q=Dq(Iq(conj(q_txyz_3, conj_type=i), [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1]).expand()
            tag = f"D{D_conjugate[2]} I{I_conjugate[2]} F{i_conj[i]}"
            print(tag)
            display(DI_q.t)
            all_t.add(ID_q.t)
            key = str(DI_q.t)
            all_t_tags[key] = tag
            all_x.add(DI_q.x)
            key = str(DI_q.x)
            all_x_tags[key] = tag
            all_y.add(DI_q.y)
            key = str(DI_q.y)
            all_y_tags[key] = tag
            all_z.add(DI_q.z)
            key = str(DI_q.z)
            all_z_tags[key] = tag

for I_conjugate in conjugates:
    for D_conjugate in conjugates:
        DI_q=Dq(Iq(q_txyz_3, [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1], reverse=True), [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]).expand()
        tag = f"Rev D{D_conjugate[2]} I{I_conjugate[2]} F"
        print(tag)
        display(DI_q.t)
        all_t.add(DI_q.t)
        key = str(DI_q.t)
        all_t_tags[key] = tag
        all_x.add(DI_q.x)
        key = str(DI_q.x)
        all_x_tags[key] = tag
        all_y.add(DI_q.y)
        key = str(DI_q.y)
        all_y_tags[key] = tag
        all_z.add(DI_q.z)
        key = str(DI_q.z)
        all_z_tags[key] = tag
        
        for i in range(3):
            DI_q=Dq(Iq(conj(q_txyz_3, conj_type=i), [t, x, y, z], [t, x, y, z], conj=I_conjugate[0], conj_type=I_conjugate[1], reverse=True), [t, x, y, z], [t, x, y, z], conj=D_conjugate[0], conj_type=D_conjugate[1]).expand()
            tag = f"Rev D{D_conjugate[2]} I{I_conjugate[2]} F{i_conj[i]}"
            print(tag)
            display(DI_q.t)
            all_t.add(DI_q.t)
            key = str(DI_q.t)
            all_t_tags[key] = tag
            all_x.add(DI_q.x)
            key = str(DI_q.x)
            all_x_tags[key] = tag
            all_y.add(DI_q.y)
            key = str(DI_q.y)
            all_y_tags[key] = tag
            all_z.add(DI_q.z)
            key = str(DI_q.z)
            all_z_tags[key] = tag
        
#for all_ID_q in all_ID_qs:
#    all_ID_q.display()
# Out:
# I D F
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I D F*
#    3        2        2        2
# 4⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I D F*1
#       2
# -2⋅t⋅x
# I D F*2
#       2
# -2⋅t⋅y
# I D* F
#    3         2         2         2
# 4⋅t  - 14⋅t⋅x  - 14⋅t⋅y  - 14⋅t⋅z
# I D* F*
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I D* F*1
#      3        2         2         2
# - 2⋅t  + 2⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# I D* F*2
#      3         2        2         2
# - 2⋅t  + 12⋅t⋅x  + 2⋅t⋅y  + 12⋅t⋅z
# I D*1 F
#       2
# 10⋅t⋅x
# I D*1 F*
#      3        2
# - 2⋅t  + 2⋅t⋅x
# I D*1 F*1
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I D*1 F*2
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# I D*2 F
#       2
# 10⋅t⋅y
# I D*2 F*
#      3        2
# - 2⋅t  + 2⋅t⋅y
# I D*2 F*1
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# I D*2 F*2
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I* D F
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I* D F*
#    3         2         2         2
# 4⋅t  - 14⋅t⋅x  - 14⋅t⋅y  - 14⋅t⋅z
# I* D F*1
#       2
# 10⋅t⋅x
# I* D F*2
#       2
# 10⋅t⋅y
# I* D* F
#    3        2        2        2
# 4⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I* D* F*
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I* D* F*1
#      3        2
# - 2⋅t  + 2⋅t⋅x
# I* D* F*2
#      3        2
# - 2⋅t  + 2⋅t⋅y
# I* D*1 F
#       2
# -2⋅t⋅x
# I* D*1 F*
#      3        2         2         2
# - 2⋅t  + 2⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# I* D*1 F*1
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I* D*1 F*2
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# I* D*2 F
#       2
# -2⋅t⋅y
# I* D*2 F*
#      3         2        2         2
# - 2⋅t  + 12⋅t⋅x  + 2⋅t⋅y  + 12⋅t⋅z
# I* D*2 F*1
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# I* D*2 F*2
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I*1 D F
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*1 D F*
#      3         2        2        2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# I*1 D F*1
#        2
# -10⋅t⋅x
# I*1 D F*2
#      2
# 2⋅t⋅y  - 8⋅x⋅y⋅z
# I*1 D* F
#      3        2         2         2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
# I*1 D* F*
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*1 D* F*1
#    3        2         2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# I*1 D* F*2
#    3        2         2
# 2⋅t  - 2⋅t⋅y  - 12⋅t⋅z  + 8⋅x⋅y⋅z
# I*1 D*1 F
#      2
# 2⋅t⋅x
# I*1 D*1 F*
#    3        2
# 2⋅t  - 2⋅t⋅x
# I*1 D*1 F*1
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*1 D*1 F*2
#      3        2
# - 2⋅t  + 2⋅t⋅z
# I*1 D*2 F
#         2
# - 10⋅t⋅y  + 8⋅x⋅y⋅z
# I*1 D*2 F*
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 8⋅x⋅y⋅z
# I*1 D*2 F*1
#      3         2         2        2
# - 2⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 2⋅t⋅z
# I*1 D*2 F*2
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*2 D F
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*2 D F*
#      3        2         2        2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 2⋅t⋅z
# I*2 D F*1
#      2
# 2⋅t⋅x  + 8⋅x⋅y⋅z
# I*2 D F*2
#        2
# -10⋅t⋅y
# I*2 D* F
#      3         2        2         2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 14⋅t⋅z
# I*2 D* F*
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*2 D* F*1
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅z  - 8⋅x⋅y⋅z
# I*2 D* F*2
#    3         2        2         2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z
# I*2 D*1 F
#         2
# - 10⋅t⋅x  - 8⋅x⋅y⋅z
# I*2 D*1 F*
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  + 8⋅x⋅y⋅z
# I*2 D*1 F*1
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# I*2 D*1 F*2
#      3         2         2        2
# - 2⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 2⋅t⋅z
# I*2 D*2 F
#      2
# 2⋅t⋅y
# I*2 D*2 F*
#    3        2
# 2⋅t  - 2⋅t⋅y
# I*2 D*2 F*1
#      3        2
# - 2⋅t  + 2⋅t⋅z
# I*2 D*2 F*2
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I D F
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I D F*
#    3        2        2        2
# 4⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I D F*1
#       2
# -2⋅t⋅x
# Rev I D F*2
#       2
# -2⋅t⋅y
# Rev I D* F
#    3         2         2         2
# 4⋅t  - 14⋅t⋅x  - 14⋅t⋅y  - 14⋅t⋅z
# Rev I D* F*
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I D* F*1
#      3        2         2         2
# - 2⋅t  + 2⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# Rev I D* F*2
#      3         2        2         2
# - 2⋅t  + 12⋅t⋅x  + 2⋅t⋅y  + 12⋅t⋅z
# Rev I D*1 F
#       2
# 10⋅t⋅x
# Rev I D*1 F*
#      3        2
# - 2⋅t  + 2⋅t⋅x
# Rev I D*1 F*1
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I D*1 F*2
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# Rev I D*2 F
#       2
# 10⋅t⋅y
# Rev I D*2 F*
#      3        2
# - 2⋅t  + 2⋅t⋅y
# Rev I D*2 F*1
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# Rev I D*2 F*2
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I* D F
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I* D F*
#    3         2         2         2
# 4⋅t  - 14⋅t⋅x  - 14⋅t⋅y  - 14⋅t⋅z
# Rev I* D F*1
#       2
# 10⋅t⋅x
# Rev I* D F*2
#       2
# 10⋅t⋅y
# Rev I* D* F
#    3        2        2        2
# 4⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I* D* F*
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I* D* F*1
#      3        2
# - 2⋅t  + 2⋅t⋅x
# Rev I* D* F*2
#      3        2
# - 2⋅t  + 2⋅t⋅y
# Rev I* D*1 F
#       2
# -2⋅t⋅x
# Rev I* D*1 F*
#      3        2         2         2
# - 2⋅t  + 2⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# Rev I* D*1 F*1
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I* D*1 F*2
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# Rev I* D*2 F
#       2
# -2⋅t⋅y
# Rev I* D*2 F*
#      3         2        2         2
# - 2⋅t  + 12⋅t⋅x  + 2⋅t⋅y  + 12⋅t⋅z
# Rev I* D*2 F*1
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# Rev I* D*2 F*2
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I*1 D F
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*1 D F*
#      3         2        2        2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev I*1 D F*1
#        2
# -10⋅t⋅x
# Rev I*1 D F*2
#      2
# 2⋅t⋅y  + 8⋅x⋅y⋅z
# Rev I*1 D* F
#      3        2         2         2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
# Rev I*1 D* F*
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*1 D* F*1
#    3        2         2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# Rev I*1 D* F*2
#    3        2         2
# 2⋅t  - 2⋅t⋅y  - 12⋅t⋅z  - 8⋅x⋅y⋅z
# Rev I*1 D*1 F
#      2
# 2⋅t⋅x
# Rev I*1 D*1 F*
#    3        2
# 2⋅t  - 2⋅t⋅x
# Rev I*1 D*1 F*1
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*1 D*1 F*2
#      3        2
# - 2⋅t  + 2⋅t⋅z
# Rev I*1 D*2 F
#         2
# - 10⋅t⋅y  - 8⋅x⋅y⋅z
# Rev I*1 D*2 F*
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  + 8⋅x⋅y⋅z
# Rev I*1 D*2 F*1
#      3         2         2        2
# - 2⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 2⋅t⋅z
# Rev I*1 D*2 F*2
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*2 D F
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*2 D F*
#      3        2         2        2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 2⋅t⋅z
# Rev I*2 D F*1
#      2
# 2⋅t⋅x  - 8⋅x⋅y⋅z
# Rev I*2 D F*2
#        2
# -10⋅t⋅y
# Rev I*2 D* F
#      3         2        2         2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 14⋅t⋅z
# Rev I*2 D* F*
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*2 D* F*1
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅z  + 8⋅x⋅y⋅z
# Rev I*2 D* F*2
#    3         2        2         2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z
# Rev I*2 D*1 F
#         2
# - 10⋅t⋅x  + 8⋅x⋅y⋅z
# Rev I*2 D*1 F*
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 8⋅x⋅y⋅z
# Rev I*2 D*1 F*1
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev I*2 D*1 F*2
#      3         2         2        2
# - 2⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 2⋅t⋅z
# Rev I*2 D*2 F
#      2
# 2⋅t⋅y
# Rev I*2 D*2 F*
#    3        2
# 2⋅t  - 2⋅t⋅y
# Rev I*2 D*2 F*1
#      3        2
# - 2⋅t  + 2⋅t⋅z
# Rev I*2 D*2 F*2
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# D I F
#      3        2        2        2
# - 5⋅t  + 8⋅t⋅x  + 8⋅t⋅y  + 8⋅t⋅z
# D I F*
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
# D I F*1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# D I F*2
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
# D* I F
#  3        2        2        2
# t  - 4⋅t⋅x  - 4⋅t⋅y  - 4⋅t⋅z
# D* I F*
#    3         2         2         2
# 7⋅t  - 20⋅t⋅x  - 20⋅t⋅y  - 20⋅t⋅z
# D* I F*1
#      3         2        2        2
# - 3⋅t  + 16⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# D* I F*2
#      3        2         2        2
# - 3⋅t  + 6⋅t⋅x  + 16⋅t⋅y  + 6⋅t⋅z
# D*1 I F
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# D*1 I F*
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# D*1 I F*1
#    3        2
# - t  - 4⋅t⋅x
# D*1 I F*2
#    3        2        2
# - t  + 6⋅t⋅x  + 2⋅t⋅y  + 8⋅x⋅y⋅z
# D*2 I F
#    3        2        2        2
# 3⋅t  - 2⋅t⋅x  - 8⋅t⋅y  - 2⋅t⋅z
# D*2 I F*
#      3        2        2        2
# - 3⋅t  + 2⋅t⋅x  + 8⋅t⋅y  + 2⋅t⋅z
# D*2 I F*1
#    3        2        2
# - t  + 2⋅t⋅x  + 6⋅t⋅y  - 8⋅x⋅y⋅z
# D*2 I F*2
#    3        2
# - t  - 4⋅t⋅y
# D I* F
#    3         2         2         2
# 7⋅t  - 20⋅t⋅x  - 20⋅t⋅y  - 20⋅t⋅z
# D I* F*
#  3        2        2        2
# t  - 4⋅t⋅x  - 4⋅t⋅y  - 4⋅t⋅z
# D I* F*1
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 18⋅t⋅y  + 18⋅t⋅z
# D I* F*2
#      3         2        2         2
# - 5⋅t  + 18⋅t⋅x  + 8⋅t⋅y  + 18⋅t⋅z
# D* I* F
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
# D* I* F*
#      3        2        2        2
# - 5⋅t  + 8⋅t⋅x  + 8⋅t⋅y  + 8⋅t⋅z
# D* I* F*1
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# D* I* F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
# D*1 I* F
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
# D*1 I* F*
#  3        2        2        2
# t  + 4⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# D*1 I* F*1
#    3        2         2         2
# 3⋅t  - 8⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# D*1 I* F*2
#    3        2        2         2
# 3⋅t  - 6⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z  - 8⋅x⋅y⋅z
# D*2 I* F
#      3         2        2         2
# - 5⋅t  + 14⋅t⋅x  + 8⋅t⋅y  + 14⋅t⋅z
# D*2 I* F*
#  3        2        2        2
# t  - 2⋅t⋅x  + 4⋅t⋅y  - 2⋅t⋅z
# D*2 I* F*1
#    3        2        2         2
# 3⋅t  - 2⋅t⋅x  - 6⋅t⋅y  - 12⋅t⋅z  + 8⋅x⋅y⋅z
# D*2 I* F*2
#    3         2        2         2
# 3⋅t  - 12⋅t⋅x  - 8⋅t⋅y  - 12⋅t⋅z
# D I*1 F
#  3        2
# t  + 4⋅t⋅x
# D I*1 F*
#    3        2
# - t  - 4⋅t⋅x
# D I*1 F*1
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# D I*1 F*2
#  3        2        2
# t  - 6⋅t⋅x  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# D* I*1 F
#    3        2
# - t  + 4⋅t⋅x
# D* I*1 F*
#      3        2         2         2
# - 3⋅t  + 8⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# D* I*1 F*1
#    3        2        2        2
# - t  - 4⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# D* I*1 F*2
#    3        2         2        2
# 3⋅t  - 6⋅t⋅x  - 12⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# D*1 I*1 F
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# D*1 I*1 F*
#    3        2        2        2
# - t  + 4⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# D*1 I*1 F*1
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z
# D*1 I*1 F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 6⋅t⋅y  - 4⋅t⋅z
# D*2 I*1 F
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# D*2 I*1 F*
#    3        2         2        2
# 3⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# D*2 I*1 F*1
#  3        2        2        2
# t  - 2⋅t⋅x  - 2⋅t⋅y  + 4⋅t⋅z
# D*2 I*1 F*2
#      3         2         2        2
# - 3⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 8⋅t⋅z
# D I*2 F
#  3        2
# t  + 4⋅t⋅y
# D I*2 F*
#    3        2
# - t  - 4⋅t⋅y
# D I*2 F*1
#  3        2        2
# t  - 6⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# D I*2 F*2
#      3        2        2        2
# - 3⋅t  + 2⋅t⋅x  + 8⋅t⋅y  + 2⋅t⋅z
# D* I*2 F
#    3        2
# - t  + 4⋅t⋅y
# D* I*2 F*
#      3         2        2         2
# - 3⋅t  + 12⋅t⋅x  + 8⋅t⋅y  + 12⋅t⋅z
# D* I*2 F*1
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 6⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# D* I*2 F*2
#    3        2        2        2
# - t  + 2⋅t⋅x  - 4⋅t⋅y  + 2⋅t⋅z
# D*1 I*2 F
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# D*1 I*2 F*
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# D*1 I*2 F*1
#      3         2         2        2
# - 3⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 8⋅t⋅z
# D*1 I*2 F*2
#  3        2        2        2
# t  - 2⋅t⋅x  - 2⋅t⋅y  + 4⋅t⋅z
# D*2 I*2 F
#      3        2        2        2
# - 3⋅t  + 6⋅t⋅x  + 8⋅t⋅y  + 6⋅t⋅z
# D*2 I*2 F*
#    3        2        2        2
# - t  + 6⋅t⋅x  + 4⋅t⋅y  + 6⋅t⋅z
# D*2 I*2 F*1
#  3        2        2        2
# t  - 6⋅t⋅x  - 6⋅t⋅y  - 4⋅t⋅z
# D*2 I*2 F*2
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z
# Rev D I F
#      3        2        2        2
# - 5⋅t  + 8⋅t⋅x  + 8⋅t⋅y  + 8⋅t⋅z
# Rev D I F*
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
# Rev D I F*1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D I F*2
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
# Rev D* I F
#    3         2         2         2
# 7⋅t  - 20⋅t⋅x  - 20⋅t⋅y  - 20⋅t⋅z
# Rev D* I F*
#  3        2        2        2
# t  - 4⋅t⋅x  - 4⋅t⋅y  - 4⋅t⋅z
# Rev D* I F*1
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 18⋅t⋅y  + 18⋅t⋅z
# Rev D* I F*2
#      3         2        2         2
# - 5⋅t  + 18⋅t⋅x  + 8⋅t⋅y  + 18⋅t⋅z
# Rev D*1 I F
#  3        2
# t  + 4⋅t⋅x
# Rev D*1 I F*
#    3        2
# - t  - 4⋅t⋅x
# Rev D*1 I F*1
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev D*1 I F*2
#  3        2        2
# t  - 6⋅t⋅x  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*2 I F
#  3        2
# t  + 4⋅t⋅y
# Rev D*2 I F*
#    3        2
# - t  - 4⋅t⋅y
# Rev D*2 I F*1
#  3        2        2
# t  - 6⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*2 I F*2
#      3        2        2        2
# - 3⋅t  + 2⋅t⋅x  + 8⋅t⋅y  + 2⋅t⋅z
# Rev D I* F
#  3        2        2        2
# t  - 4⋅t⋅x  - 4⋅t⋅y  - 4⋅t⋅z
# Rev D I* F*
#    3         2         2         2
# 7⋅t  - 20⋅t⋅x  - 20⋅t⋅y  - 20⋅t⋅z
# Rev D I* F*1
#      3         2        2        2
# - 3⋅t  + 16⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# Rev D I* F*2
#      3        2         2        2
# - 3⋅t  + 6⋅t⋅x  + 16⋅t⋅y  + 6⋅t⋅z
# Rev D* I* F
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
# Rev D* I* F*
#      3        2        2        2
# - 5⋅t  + 8⋅t⋅x  + 8⋅t⋅y  + 8⋅t⋅z
# Rev D* I* F*1
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D* I* F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
# Rev D*1 I* F
#    3        2
# - t  + 4⋅t⋅x
# Rev D*1 I* F*
#      3        2         2         2
# - 3⋅t  + 8⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
# Rev D*1 I* F*1
#    3        2        2        2
# - t  - 4⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev D*1 I* F*2
#    3        2         2        2
# 3⋅t  - 6⋅t⋅x  - 12⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*2 I* F
#    3        2
# - t  + 4⋅t⋅y
# Rev D*2 I* F*
#      3         2        2         2
# - 3⋅t  + 12⋅t⋅x  + 8⋅t⋅y  + 12⋅t⋅z
# Rev D*2 I* F*1
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 6⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*2 I* F*2
#    3        2        2        2
# - t  + 2⋅t⋅x  - 4⋅t⋅y  + 2⋅t⋅z
# Rev D I*1 F
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev D I*1 F*
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev D I*1 F*1
#    3        2
# - t  - 4⋅t⋅x
# Rev D I*1 F*2
#    3        2        2
# - t  + 6⋅t⋅x  + 2⋅t⋅y  - 8⋅x⋅y⋅z
# Rev D* I*1 F
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
# Rev D* I*1 F*
#  3        2        2        2
# t  + 4⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
# Rev D* I*1 F*1
#    3        2         2         2
# 3⋅t  - 8⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# Rev D* I*1 F*2
#    3        2        2         2
# 3⋅t  - 6⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*1 I*1 F
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# Rev D*1 I*1 F*
#    3        2        2        2
# - t  + 4⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
# Rev D*1 I*1 F*1
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z
# Rev D*1 I*1 F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 6⋅t⋅y  - 4⋅t⋅z
# Rev D*2 I*1 F
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*2 I*1 F*
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*2 I*1 F*1
#      3         2         2        2
# - 3⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 8⋅t⋅z
# Rev D*2 I*1 F*2
#  3        2        2        2
# t  - 2⋅t⋅x  - 2⋅t⋅y  + 4⋅t⋅z
# Rev D I*2 F
#    3        2        2        2
# 3⋅t  - 2⋅t⋅x  - 8⋅t⋅y  - 2⋅t⋅z
# Rev D I*2 F*
#      3        2        2        2
# - 3⋅t  + 2⋅t⋅x  + 8⋅t⋅y  + 2⋅t⋅z
# Rev D I*2 F*1
#    3        2        2
# - t  + 2⋅t⋅x  + 6⋅t⋅y  + 8⋅x⋅y⋅z
# Rev D I*2 F*2
#    3        2
# - t  - 4⋅t⋅y
# Rev D* I*2 F
#      3         2        2         2
# - 5⋅t  + 14⋅t⋅x  + 8⋅t⋅y  + 14⋅t⋅z
# Rev D* I*2 F*
#  3        2        2        2
# t  - 2⋅t⋅x  + 4⋅t⋅y  - 2⋅t⋅z
# Rev D* I*2 F*1
#    3        2        2         2
# 3⋅t  - 2⋅t⋅x  - 6⋅t⋅y  - 12⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D* I*2 F*2
#    3         2        2         2
# 3⋅t  - 12⋅t⋅x  - 8⋅t⋅y  - 12⋅t⋅z
# Rev D*1 I*2 F
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*1 I*2 F*
#    3        2         2        2
# 3⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*1 I*2 F*1
#  3        2        2        2
# t  - 2⋅t⋅x  - 2⋅t⋅y  + 4⋅t⋅z
# Rev D*1 I*2 F*2
#      3         2         2        2
# - 3⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 8⋅t⋅z
# Rev D*2 I*2 F
#      3        2        2        2
# - 3⋅t  + 6⋅t⋅x  + 8⋅t⋅y  + 6⋅t⋅z
# Rev D*2 I*2 F*
#    3        2        2        2
# - t  + 6⋅t⋅x  + 4⋅t⋅y  + 6⋅t⋅z
# Rev D*2 I*2 F*1
#  3        2        2        2
# t  - 6⋅t⋅x  - 6⋅t⋅y  - 4⋅t⋅z
# Rev D*2 I*2 F*2
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z

# %%
for all_ID_q in all_t:
    display(all_ID_q)
# Out:
#    3        2
# 2⋅t  - 2⋅t⋅x
#      3        2        2        2
# - 2⋅t  + 2⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
#      2
# 2⋅t⋅x  - 8⋅x⋅y⋅z
#    3        2        2        2
# - t  + 2⋅t⋅x  - 4⋅t⋅y  + 2⋅t⋅z
#       2
# -2⋅t⋅x
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z
#    3         2         2         2
# 4⋅t  - 14⋅t⋅x  - 14⋅t⋅y  - 14⋅t⋅z
#      3         2        2        2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
#      2
# 2⋅t⋅x  + 8⋅x⋅y⋅z
#  3        2        2        2
# t  - 4⋅t⋅x  - 4⋅t⋅y  - 4⋅t⋅z
#    3        2         2         2
# 3⋅t  - 8⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
#    3        2        2         2
# 3⋅t  - 2⋅t⋅x  - 6⋅t⋅y  - 12⋅t⋅z  - 8⋅x⋅y⋅z
#      3        2         2         2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
#    3        2        2
# - t  + 2⋅t⋅x  + 6⋅t⋅y  + 8⋅x⋅y⋅z
#      2
# 2⋅t⋅y  - 8⋅x⋅y⋅z
#    3        2
# - t  - 4⋅t⋅x
#      3        2         2        2
# - 3⋅t  + 6⋅t⋅x  + 16⋅t⋅y  + 6⋅t⋅z
#      2
# 2⋅t⋅y  + 8⋅x⋅y⋅z
#      3        2         2        2
# - 4⋅t  + 2⋅t⋅x  + 14⋅t⋅y  + 2⋅t⋅z
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  - 8⋅x⋅y⋅z
#      3         2         2        2
# - 2⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 2⋅t⋅z
#  3        2        2
# t  - 6⋅t⋅x  - 2⋅t⋅z  + 8⋅x⋅y⋅z
#      3        2         2         2
# - 2⋅t  + 2⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅z  + 8⋅x⋅y⋅z
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
#         2
# - 10⋅t⋅y  - 8⋅x⋅y⋅z
#  3        2
# t  + 4⋅t⋅x
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
#      2
# 2⋅t⋅x
#    3        2        2        2
# - t  + 4⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
#        2
# -10⋅t⋅x
#    3         2        2
# 2⋅t  - 12⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
#    3        2
# - t  + 4⋅t⋅x
#         2
# - 10⋅t⋅y  + 8⋅x⋅y⋅z
#    3         2         2         2
# 7⋅t  - 20⋅t⋅x  - 20⋅t⋅y  - 20⋅t⋅z
#  3        2        2        2
# t  - 6⋅t⋅x  - 6⋅t⋅y  - 4⋅t⋅z
#    3        2         2        2
# 3⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 8⋅x⋅y⋅z
#      3         2        2         2
# - 4⋅t  + 14⋅t⋅x  + 2⋅t⋅y  + 14⋅t⋅z
#         2
# - 10⋅t⋅x  - 8⋅x⋅y⋅z
#      3         2        2         2
# - 2⋅t  + 12⋅t⋅x  + 2⋅t⋅y  + 12⋅t⋅z
#    3         2        2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  + 8⋅x⋅y⋅z
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 6⋅t⋅y  - 2⋅t⋅z  + 8⋅x⋅y⋅z
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#         2
# - 10⋅t⋅x  + 8⋅x⋅y⋅z
#       2
# -2⋅t⋅y
#    3         2        2         2
# 3⋅t  - 12⋅t⋅x  - 8⋅t⋅y  - 12⋅t⋅z
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#  3        2        2        2
# t  - 2⋅t⋅x  + 4⋅t⋅y  - 2⋅t⋅z
#    3        2        2        2
# 4⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
#    3        2        2         2
# 3⋅t  - 6⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z  + 8⋅x⋅y⋅z
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
#  3        2
# t  + 4⋅t⋅y
#    3        2
# - t  + 4⋅t⋅y
#  3        2        2        2
# t  + 4⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
#      3        2
# - 2⋅t  + 2⋅t⋅x
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
#      3         2        2         2
# - 5⋅t  + 14⋅t⋅x  + 8⋅t⋅y  + 14⋅t⋅z
#       2
# 10⋅t⋅x
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
#        2
# -10⋅t⋅y
#      3        2        2        2
# - 5⋅t  + 8⋅t⋅x  + 8⋅t⋅y  + 8⋅t⋅z
#    3        2         2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
#    3        2        2
# - t  + 6⋅t⋅x  + 2⋅t⋅y  - 8⋅x⋅y⋅z
#  3        2        2
# t  - 6⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#    3        2
# 2⋅t  - 2⋅t⋅y
#    3        2        2        2
# 2⋅t  - 2⋅t⋅x  - 2⋅t⋅y  - 2⋅t⋅z
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 18⋅t⋅y  + 18⋅t⋅z
#    3        2        2        2
# - t  + 6⋅t⋅x  + 4⋅t⋅y  + 6⋅t⋅z
#  3        2        2        2
# t  - 2⋅t⋅x  - 2⋅t⋅y  + 4⋅t⋅z
#      3        2
# - 2⋅t  + 2⋅t⋅y
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 8⋅x⋅y⋅z
#      3         2         2        2
# - 3⋅t  + 12⋅t⋅x  + 12⋅t⋅y  + 8⋅t⋅z
#    3        2        2        2
# - t  - 4⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
#      3         2        2        2
# - 3⋅t  + 16⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
#    3        2         2
# 2⋅t  - 2⋅t⋅y  - 12⋅t⋅z  - 8⋅x⋅y⋅z
#    3        2         2        2
# 3⋅t  - 6⋅t⋅x  - 12⋅t⋅y  - 2⋅t⋅z  - 8⋅x⋅y⋅z
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅y  + 8⋅x⋅y⋅z
#    3        2         2
# 2⋅t  - 2⋅t⋅y  - 12⋅t⋅z  + 8⋅x⋅y⋅z
#    3        2
# - t  - 4⋅t⋅y
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#      3         2        2         2
# - 3⋅t  + 12⋅t⋅x  + 8⋅t⋅y  + 12⋅t⋅z
#      3        2        2        2
# - 3⋅t  + 2⋅t⋅x  + 8⋅t⋅y  + 2⋅t⋅z
#      3        2         2         2
# - 3⋅t  + 8⋅t⋅x  + 12⋅t⋅y  + 12⋅t⋅z
#      2
# 2⋅t⋅y
#      3         2        2         2
# - 5⋅t  + 18⋅t⋅x  + 8⋅t⋅y  + 18⋅t⋅z
#    3        2        2        2
# 3⋅t  - 2⋅t⋅x  - 8⋅t⋅y  - 2⋅t⋅z
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅z  - 8⋅x⋅y⋅z
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
#      3        2
# - 2⋅t  + 2⋅t⋅z
#    3        2         2
# 2⋅t  - 2⋅t⋅x  - 12⋅t⋅z  + 8⋅x⋅y⋅z
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
#      3        2        2        2
# - 3⋅t  + 6⋅t⋅x  + 8⋅t⋅y  + 6⋅t⋅z
#       2
# 10⋅t⋅y
#    3         2        2         2
# 2⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 12⋅t⋅z

# %%
ok = 0
for q1 in list(all_t):
    for q2 in list(all_t):
        q12 = q1 + q2
        
        if q12 == 4 * t**3 - 12 * t * x**2 - 12 * t * y ** 2 - 12 * t * z **2:

            key = str(q1)
            
            print(f"{ok + 1}. {all_t_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_t_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. Rev D*1 I*2 F*
#    3        2         2        2
# 3⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*1 I*2 F
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 2. Rev D*1 I*2 F
#  3         2        2
# t  - 10⋅t⋅x  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*1 I*2 F*
#    3        2         2        2
# 3⋅t  - 2⋅t⋅x  - 12⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 3. Rev D*2 I*1 F*
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
# Rev D*2 I*1 F
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 4. Rev D*2 I*1 F
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
# Rev D*2 I*1 F*
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 5. Rev D* I* F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
# Rev D I F*2
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 6. Rev D I F*1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D* I* F*1
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 7. Rev D* I* F*1
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D I F*1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 8. Rev D I F*2
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
# Rev D* I* F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# OK: 8

# %%
ok = 0
for q1 in list(all_t):
    for q2 in list(all_t):
        q12 = q1 - q2
        
        if q12 == 4 * t**3 - 12 * t * x**2 - 12 * t * y ** 2 - 12 * t * z **2:

            key = str(q1)
            
            print(f"{ok + 1}. {all_t_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_t_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. Rev D*2 I* F*2
#    3        2        2        2
# - t  + 2⋅t⋅x  - 4⋅t⋅y  + 2⋅t⋅z
# Rev D* I*2 F
#      3         2        2         2
# - 5⋅t  + 14⋅t⋅x  + 8⋅t⋅y  + 14⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 2. Rev D*2 I*2 F*2
#    3        2        2        2
# 5⋅t  - 8⋅t⋅x  - 8⋅t⋅y  - 8⋅t⋅z
# Rev D* I* F
#  3        2        2        2
# t  + 4⋅t⋅x  + 4⋅t⋅y  + 4⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 3. Rev D* I*1 F*1
#    3        2         2         2
# 3⋅t  - 8⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# Rev D*1 I* F
#    3        2
# - t  + 4⋅t⋅x
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 4. Rev D* I*2 F*2
#    3         2        2         2
# 3⋅t  - 12⋅t⋅x  - 8⋅t⋅y  - 12⋅t⋅z
# Rev D*2 I* F
#    3        2
# - t  + 4⋅t⋅y
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 5. Rev D* I* F*2
#  3        2        2        2
# t  - 6⋅t⋅x  - 4⋅t⋅y  - 6⋅t⋅z
# Rev D*2 I*2 F
#      3        2        2        2
# - 3⋅t  + 6⋅t⋅x  + 8⋅t⋅y  + 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 6. Rev D I F*1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D*1 I*1 F*
#    3        2        2        2
# - t  + 4⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 7. Rev D*1 I* F*1
#    3        2        2        2
# - t  - 4⋅t⋅x  + 2⋅t⋅y  + 2⋅t⋅z
# Rev D* I*1 F
#      3        2         2         2
# - 5⋅t  + 8⋅t⋅x  + 14⋅t⋅y  + 14⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 8. Rev D* I* F*1
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
# Rev D*1 I*1 F
#      3        2        2        2
# - 3⋅t  + 8⋅t⋅x  + 6⋅t⋅y  + 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# 9. Rev D I F*2
#    3        2        2        2
# 3⋅t  - 6⋅t⋅x  - 8⋅t⋅y  - 6⋅t⋅z
# Rev D*2 I*2 F*
#    3        2        2        2
# - t  + 6⋅t⋅x  + 4⋅t⋅y  + 6⋅t⋅z
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
# OK: 9

# %%
ok = 0
for q1 in list(all_x):
    for q2 in list(all_x):
        q12 = q1 + q2
        
        if q12 == 12 * t ** 2 * x - 4 * x ** 3 - 4 * x * y ** 2 - 4 * x * z ** 2:

            key = str(q1)
            
            print(f"{ok + 1}. {all_x_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_x_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. Rev D*1 I*1 F
#              3
#     2     5⋅x         2        2
# 12⋅t ⋅x - ──── - 4⋅x⋅y  - 4⋅x⋅z
#            3
# Rev D*1 I*1 F*1
#     3
# -7⋅x
# ──────
#   3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 2. D*1 I*2 F
#             3        2
# 16⋅t⋅y⋅z - x  + 4⋅x⋅z
# D*1 I*2 F*1
#     2                   3        2        2
# 12⋅t ⋅x - 16⋅t⋅y⋅z - 3⋅x  - 4⋅x⋅y  - 8⋅x⋅z
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 3. Rev D*1 I*1 F*1
#     3
# -7⋅x
# ──────
#   3
# Rev D*1 I*1 F
#              3
#     2     5⋅x         2        2
# 12⋅t ⋅x - ──── - 4⋅x⋅y  - 4⋅x⋅z
#            3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 4. D*2 I*1 F
#                          3
#     2                11⋅x         2         2
# 18⋅t ⋅x - 24⋅t⋅y⋅z - ───── - 8⋅x⋅y  - 10⋅x⋅z
#                        3
# D*2 I*1 F*1
#                        3
#      2                x         2        2
# - 6⋅t ⋅x + 24⋅t⋅y⋅z - ── + 4⋅x⋅y  + 6⋅x⋅z
#                       3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 5. Rev D*1 I*2 F
#             3
#    2     7⋅x         2
# 6⋅t ⋅x - ──── - 2⋅x⋅z
#           3
# Rev D*1 I*2 F*1
#             3
#    2     5⋅x         2        2
# 6⋅t ⋅x - ──── - 4⋅x⋅y  - 2⋅x⋅z
#           3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 6. Rev D* I*1 F*1
#    3
#   x         2        2
# - ── + 4⋅x⋅y  + 4⋅x⋅z
#   3
# Rev D* I*1 F
#               3
#     2     11⋅x         2        2
# 12⋅t ⋅x - ───── - 8⋅x⋅y  - 8⋅x⋅z
#             3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 7. Rev D* I* F
#    3
#   x         2        2
# - ── + 6⋅x⋅y  + 6⋅x⋅z
#   3
# Rev D* I* F*1
#               3
#     2     11⋅x          2         2
# 12⋅t ⋅x - ───── - 10⋅x⋅y  - 10⋅x⋅z
#             3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 8. Rev D*2 I*1 F
#             3        2
# 16⋅t⋅y⋅z - x  + 4⋅x⋅y
# Rev D*2 I*1 F*1
#     2                   3        2        2
# 12⋅t ⋅x - 16⋅t⋅y⋅z - 3⋅x  - 8⋅x⋅y  - 4⋅x⋅z
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 9. Rev D*2 I*1 F*1
#     2                   3        2        2
# 12⋅t ⋅x - 16⋅t⋅y⋅z - 3⋅x  - 8⋅x⋅y  - 4⋅x⋅z
# Rev D*2 I*1 F
#             3        2
# 16⋅t⋅y⋅z - x  + 4⋅x⋅y
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 10. Rev D* I* F*1
#               3
#     2     11⋅x          2         2
# 12⋅t ⋅x - ───── - 10⋅x⋅y  - 10⋅x⋅z
#             3
# Rev D* I* F
#    3
#   x         2        2
# - ── + 6⋅x⋅y  + 6⋅x⋅z
#   3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 11. Rev D*1 I* F*1
#              3
#     2     5⋅x         2        2
# 12⋅t ⋅x - ──── - 2⋅x⋅y  - 2⋅x⋅z
#            3
# Rev D*1 I* F
#      3
#   7⋅x         2        2
# - ──── - 2⋅x⋅y  - 2⋅x⋅z
#    3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 12. Rev D*2 I*2 F*1
#    2                 3        2        2
# 6⋅t ⋅x - 16⋅t⋅y⋅z - x  + 4⋅x⋅y  - 2⋅x⋅z
# Rev D*2 I*2 F
#    2                   3        2        2
# 6⋅t ⋅x + 16⋅t⋅y⋅z - 3⋅x  - 8⋅x⋅y  - 2⋅x⋅z
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 13. Rev D*2 I*2 F
#    2                   3        2        2
# 6⋅t ⋅x + 16⋅t⋅y⋅z - 3⋅x  - 8⋅x⋅y  - 2⋅x⋅z
# Rev D*2 I*2 F*1
#    2                 3        2        2
# 6⋅t ⋅x - 16⋅t⋅y⋅z - x  + 4⋅x⋅y  - 2⋅x⋅z
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 14. D*1 I*2 F*1
#     2                   3        2        2
# 12⋅t ⋅x - 16⋅t⋅y⋅z - 3⋅x  - 4⋅x⋅y  - 8⋅x⋅z
# D*1 I*2 F
#             3        2
# 16⋅t⋅y⋅z - x  + 4⋅x⋅z
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 15. Rev D*1 I* F
#      3
#   7⋅x         2        2
# - ──── - 2⋅x⋅y  - 2⋅x⋅z
#    3
# Rev D*1 I* F*1
#              3
#     2     5⋅x         2        2
# 12⋅t ⋅x - ──── - 2⋅x⋅y  - 2⋅x⋅z
#            3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 16. Rev D*1 I*2 F*1
#             3
#    2     5⋅x         2        2
# 6⋅t ⋅x - ──── - 4⋅x⋅y  - 2⋅x⋅z
#           3
# Rev D*1 I*2 F
#             3
#    2     7⋅x         2
# 6⋅t ⋅x - ──── - 2⋅x⋅z
#           3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 17. D*2 I*1 F*1
#                        3
#      2                x         2        2
# - 6⋅t ⋅x + 24⋅t⋅y⋅z - ── + 4⋅x⋅y  + 6⋅x⋅z
#                       3
# D*2 I*1 F
#                          3
#     2                11⋅x         2         2
# 18⋅t ⋅x - 24⋅t⋅y⋅z - ───── - 8⋅x⋅y  - 10⋅x⋅z
#                        3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# 18. Rev D* I*1 F
#               3
#     2     11⋅x         2        2
# 12⋅t ⋅x - ───── - 8⋅x⋅y  - 8⋅x⋅z
#             3
# Rev D* I*1 F*1
#    3
#   x         2        2
# - ── + 4⋅x⋅y  + 4⋅x⋅z
#   3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 4⋅x⋅y  - 4⋅x⋅z
# OK: 18

# %%
ok = 0
for q1 in list(all_y):
    for q2 in list(all_y):
        q12 = q1 + q2
        
        if q12 == 12 * t ** 2 * y - 4 * x ** 2 * y - 4 * y ** 3 - 4 * y * z ** 2:

            key = str(q1)
            
            print(f"{ok + 1}. {all_y_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_y_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. D*1 I*2 F*2
#                                 3
#      2                   2     y         2
# - 6⋅t ⋅y - 24⋅t⋅x⋅z + 4⋅x ⋅y - ── + 6⋅y⋅z
#                                3
# D*1 I*2 F
#                                   3
#     2                   2     11⋅y          2
# 18⋅t ⋅y + 24⋅t⋅x⋅z - 8⋅x ⋅y - ───── - 10⋅y⋅z
#                                 3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 2. Rev D*2 I*1 F
#             3
#    2     7⋅y         2
# 6⋅t ⋅y - ──── - 2⋅y⋅z
#           3
# Rev D*2 I*1 F*2
#                      3
#    2        2     5⋅y         2
# 6⋅t ⋅y - 4⋅x ⋅y - ──── - 2⋅y⋅z
#                    3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 3. D*2 I*1 F*2
#     2                   2        3        2
# 12⋅t ⋅y + 16⋅t⋅x⋅z - 4⋅x ⋅y - 3⋅y  - 8⋅y⋅z
# D*2 I*1 F
#              3        2
# -16⋅t⋅x⋅z - y  + 4⋅y⋅z
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 4. D*2 I*1 F
#              3        2
# -16⋅t⋅x⋅z - y  + 4⋅y⋅z
# D*2 I*1 F*2
#     2                   2        3        2
# 12⋅t ⋅y + 16⋅t⋅x⋅z - 4⋅x ⋅y - 3⋅y  - 8⋅y⋅z
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 5. Rev D*1 I*2 F*2
#     2                   2        3        2
# 12⋅t ⋅y + 16⋅t⋅x⋅z - 8⋅x ⋅y - 3⋅y  - 4⋅y⋅z
# Rev D*1 I*2 F
#                2      3
# -16⋅t⋅x⋅z + 4⋅x ⋅y - y
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 6. Rev D*2 I*2 F*2
#     3
# -7⋅y
# ──────
#   3
# Rev D*2 I*2 F
#                       3
#     2        2     5⋅y         2
# 12⋅t ⋅y - 4⋅x ⋅y - ──── - 4⋅y⋅z
#                     3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 7. D*1 I*2 F
#                                   3
#     2                   2     11⋅y          2
# 18⋅t ⋅y + 24⋅t⋅x⋅z - 8⋅x ⋅y - ───── - 10⋅y⋅z
#                                 3
# D*1 I*2 F*2
#                                 3
#      2                   2     y         2
# - 6⋅t ⋅y - 24⋅t⋅x⋅z + 4⋅x ⋅y - ── + 6⋅y⋅z
#                                3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 8. Rev D*2 I* F*2
#                       3
#     2        2     5⋅y         2
# 12⋅t ⋅y - 2⋅x ⋅y - ──── - 2⋅y⋅z
#                     3
# Rev D*2 I* F
#               3
#      2     7⋅y         2
# - 2⋅x ⋅y - ──── - 2⋅y⋅z
#             3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 9. Rev D*1 I*1 F
#    2                   2        3        2
# 6⋅t ⋅y - 16⋅t⋅x⋅z - 8⋅x ⋅y - 3⋅y  - 2⋅y⋅z
# Rev D*1 I*1 F*2
#    2                   2      3        2
# 6⋅t ⋅y + 16⋅t⋅x⋅z + 4⋅x ⋅y - y  - 2⋅y⋅z
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 10. Rev D*2 I* F
#               3
#      2     7⋅y         2
# - 2⋅x ⋅y - ──── - 2⋅y⋅z
#             3
# Rev D*2 I* F*2
#                       3
#     2        2     5⋅y         2
# 12⋅t ⋅y - 2⋅x ⋅y - ──── - 2⋅y⋅z
#                     3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 11. Rev D* I* F*2
#                         3
#     2         2     11⋅y          2
# 12⋅t ⋅y - 10⋅x ⋅y - ───── - 10⋅y⋅z
#                       3
# Rev D* I* F
#           3
#    2     y         2
# 6⋅x ⋅y - ── + 6⋅y⋅z
#          3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 12. Rev D*2 I*1 F*2
#                      3
#    2        2     5⋅y         2
# 6⋅t ⋅y - 4⋅x ⋅y - ──── - 2⋅y⋅z
#                    3
# Rev D*2 I*1 F
#             3
#    2     7⋅y         2
# 6⋅t ⋅y - ──── - 2⋅y⋅z
#           3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 13. Rev D*1 I*1 F*2
#    2                   2      3        2
# 6⋅t ⋅y + 16⋅t⋅x⋅z + 4⋅x ⋅y - y  - 2⋅y⋅z
# Rev D*1 I*1 F
#    2                   2        3        2
# 6⋅t ⋅y - 16⋅t⋅x⋅z - 8⋅x ⋅y - 3⋅y  - 2⋅y⋅z
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 14. Rev D*1 I*2 F
#                2      3
# -16⋅t⋅x⋅z + 4⋅x ⋅y - y
# Rev D*1 I*2 F*2
#     2                   2        3        2
# 12⋅t ⋅y + 16⋅t⋅x⋅z - 8⋅x ⋅y - 3⋅y  - 4⋅y⋅z
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 15. Rev D* I*2 F*2
#           3
#    2     y         2
# 4⋅x ⋅y - ── + 4⋅y⋅z
#          3
# Rev D* I*2 F
#                        3
#     2        2     11⋅y         2
# 12⋅t ⋅y - 8⋅x ⋅y - ───── - 8⋅y⋅z
#                      3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 16. Rev D*2 I*2 F
#                       3
#     2        2     5⋅y         2
# 12⋅t ⋅y - 4⋅x ⋅y - ──── - 4⋅y⋅z
#                     3
# Rev D*2 I*2 F*2
#     3
# -7⋅y
# ──────
#   3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 17. Rev D* I* F
#           3
#    2     y         2
# 6⋅x ⋅y - ── + 6⋅y⋅z
#          3
# Rev D* I* F*2
#                         3
#     2         2     11⋅y          2
# 12⋅t ⋅y - 10⋅x ⋅y - ───── - 10⋅y⋅z
#                       3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# 18. Rev D* I*2 F
#                        3
#     2        2     11⋅y         2
# 12⋅t ⋅y - 8⋅x ⋅y - ───── - 8⋅y⋅z
#                      3
# Rev D* I*2 F*2
#           3
#    2     y         2
# 4⋅x ⋅y - ── + 4⋅y⋅z
#          3
#     2        2        3        2
# 12⋅t ⋅y - 4⋅x ⋅y - 4⋅y  - 4⋅y⋅z
# OK: 18

# %%
ok = 0
for q1 in list(all_z):
    for q2 in list(all_z):
        q12 = q1 + q2
        
        if q12 == 12 * t ** 2 * z - 4 * x ** 2 * z - 4 * y ** 2 * z - 4 * z ** 3:

            key = str(q1)
            
            print(f"{ok + 1}. {all_z_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_z_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. D I F*1
#    2                  2      3
# 6⋅t ⋅z - 8⋅t⋅x⋅y + 2⋅y ⋅z - z
# Rev D*1 I*2 F*
#    2                  2        2        3
# 6⋅t ⋅z + 8⋅t⋅x⋅y - 4⋅x ⋅z - 6⋅y ⋅z - 3⋅z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 2. D I F*2
#    2                  2      3
# 6⋅t ⋅z + 8⋅t⋅x⋅y + 2⋅x ⋅z - z
# Rev D*2 I*1 F*
#    2                  2        2        3
# 6⋅t ⋅z - 8⋅t⋅x⋅y - 6⋅x ⋅z - 4⋅y ⋅z - 3⋅z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 3. Rev D*1 I*2 F*1
#                                3
#     2        2        2     5⋅z
# 12⋅t ⋅z - 2⋅x ⋅z - 2⋅y ⋅z - ────
#                              3
# D I F*
#                        3
#      2        2     7⋅z
# - 2⋅x ⋅z - 2⋅y ⋅z - ────
#                      3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 4. Rev D*1 I*2 F*
#    2                  2        2        3
# 6⋅t ⋅z + 8⋅t⋅x⋅y - 4⋅x ⋅z - 6⋅y ⋅z - 3⋅z
# D I F*1
#    2                  2      3
# 6⋅t ⋅z - 8⋅t⋅x⋅y + 2⋅y ⋅z - z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 5. D I F*
#                        3
#      2        2     7⋅z
# - 2⋅x ⋅z - 2⋅y ⋅z - ────
#                      3
# Rev D*1 I*2 F*1
#                                3
#     2        2        2     5⋅z
# 12⋅t ⋅z - 2⋅x ⋅z - 2⋅y ⋅z - ────
#                              3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 6. Rev D*2 I*1 F*
#    2                  2        2        3
# 6⋅t ⋅z - 8⋅t⋅x⋅y - 6⋅x ⋅z - 4⋅y ⋅z - 3⋅z
# D I F*2
#    2                  2      3
# 6⋅t ⋅z + 8⋅t⋅x⋅y + 2⋅x ⋅z - z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# OK: 6

# %%
ok = 0
for q1 in list(all_z):
    for q2 in list(all_z):
        q12 = q1 - q2
        
        if q12 == 12 * t ** 2 * z - 4 * x ** 2 * z - 4 * y ** 2 * z - 4 * z ** 3:

            key = str(q1)
            
            print(f"{ok + 1}. {all_z_tags[key]}")
            display(q1)
            
            key = str(q2)
            print(all_z_tags[key])
            display(q2)
            
            display(q12)
            print()
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# 1. Rev D* I*1 F*2
#     2                  2        2        3
# 12⋅t ⋅z + 8⋅t⋅x⋅y - 6⋅x ⋅z - 2⋅y ⋅z - 3⋅z
# Rev D*1 I* F
#              2        2      3
# 8⋅t⋅x⋅y - 2⋅x ⋅z + 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 2. D*1 I* F*2
#     2                  2        2        3
# 12⋅t ⋅z + 8⋅t⋅x⋅y - 2⋅x ⋅z - 6⋅y ⋅z - 3⋅z
# D* I*1 F
#              2        2      3
# 8⋅t⋅x⋅y + 2⋅x ⋅z - 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 3. D*2 I* F*1
#     2                  2        2        3
# 12⋅t ⋅z - 8⋅t⋅x⋅y - 6⋅x ⋅z - 2⋅y ⋅z - 3⋅z
# D* I*2 F
#               2        2      3
# -8⋅t⋅x⋅y - 2⋅x ⋅z + 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 4. D*1 I*2 F
#    2                   2        2        3
# 6⋅t ⋅z - 16⋅t⋅x⋅y - 8⋅x ⋅z - 2⋅y ⋅z - 3⋅z
# D*2 I*1 F*
#      2                   2        2      3
# - 6⋅t ⋅z - 16⋅t⋅x⋅y - 4⋅x ⋅z + 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 5. Rev D* I*2 F*1
#     2                  2        2        3
# 12⋅t ⋅z - 8⋅t⋅x⋅y - 2⋅x ⋅z - 6⋅y ⋅z - 3⋅z
# Rev D*2 I* F
#               2        2      3
# -8⋅t⋅x⋅y + 2⋅x ⋅z - 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 6. Rev D*2 I* F*1
#                                          3
#      2                   2        2     z
# - 6⋅t ⋅z + 24⋅t⋅x⋅y + 6⋅x ⋅z + 4⋅y ⋅z - ──
#                                         3
# Rev D* I*2 F
#                                               3
#       2                    2        2     11⋅z
# - 18⋅t ⋅z + 24⋅t⋅x⋅y + 10⋅x ⋅z + 8⋅y ⋅z + ─────
#                                             3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 7. Rev D*1 I*2 F*1
#                                3
#     2        2        2     5⋅z
# 12⋅t ⋅z - 2⋅x ⋅z - 2⋅y ⋅z - ────
#                              3
# D* I* F
#                      3
#    2        2     7⋅z
# 2⋅x ⋅z + 2⋅y ⋅z + ────
#                    3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 8. Rev D*2 I*2 F
#    2                   2        2        3
# 6⋅t ⋅z - 16⋅t⋅x⋅y - 2⋅x ⋅z - 8⋅y ⋅z - 3⋅z
# Rev D*1 I*1 F*
#      2                   2        2      3
# - 6⋅t ⋅z - 16⋅t⋅x⋅y + 2⋅x ⋅z - 4⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 9. Rev D* I* F
#                    3
#    2        2     z
# 6⋅x ⋅z + 6⋅y ⋅z - ──
#                   3
# Rev D*2 I*2 F*1
#                                     3
#       2         2         2     11⋅z
# - 12⋅t ⋅z + 10⋅x ⋅z + 10⋅y ⋅z + ─────
#                                   3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 10. Rev D*1 I*1 F
#    2                   2        2        3
# 6⋅t ⋅z + 16⋅t⋅x⋅y - 8⋅x ⋅z - 2⋅y ⋅z - 3⋅z
# Rev D*2 I*2 F*
#      2                   2        2      3
# - 6⋅t ⋅z + 16⋅t⋅x⋅y - 4⋅x ⋅z + 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 11. D*2 I*1 F
#    2                   2        2        3
# 6⋅t ⋅z + 16⋅t⋅x⋅y - 2⋅x ⋅z - 8⋅y ⋅z - 3⋅z
# D*1 I*2 F*
#      2                   2        2      3
# - 6⋅t ⋅z + 16⋅t⋅x⋅y + 2⋅x ⋅z - 4⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 12. Rev D*1 I*2 F*
#    2                  2        2        3
# 6⋅t ⋅z + 8⋅t⋅x⋅y - 4⋅x ⋅z - 6⋅y ⋅z - 3⋅z
# Rev D*2 I*1 F
#      2                  2      3
# - 6⋅t ⋅z + 8⋅t⋅x⋅y - 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 13. Rev D* I*2 F*
#                               3
#    2        2        2     5⋅z
# 6⋅t ⋅z - 4⋅x ⋅z - 2⋅y ⋅z - ────
#                             3
# D*1 I* F
#                        3
#      2        2     7⋅z
# - 6⋅t ⋅z + 2⋅y ⋅z + ────
#                      3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 14. Rev D* I*1 F*
#                               3
#    2        2        2     5⋅z
# 6⋅t ⋅z - 2⋅x ⋅z - 4⋅y ⋅z - ────
#                             3
# D*2 I* F
#                        3
#      2        2     7⋅z
# - 6⋅t ⋅z + 2⋅x ⋅z + ────
#                      3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 15. D*2 I*2 F*
#    2                  2        2        3
# 6⋅t ⋅z - 8⋅t⋅x⋅y - 4⋅x ⋅z - 6⋅y ⋅z - 3⋅z
# D*1 I*1 F
#      2                  2      3
# - 6⋅t ⋅z - 8⋅t⋅x⋅y - 2⋅y ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 16. D*1 I*1 F*
#    2                  2        2        3
# 6⋅t ⋅z + 8⋅t⋅x⋅y - 6⋅x ⋅z - 4⋅y ⋅z - 3⋅z
# D*2 I*2 F
#      2                  2      3
# - 6⋅t ⋅z + 8⋅t⋅x⋅y - 2⋅x ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 17. Rev D*1 I* F*2
#                                          3
#      2                   2        2     z
# - 6⋅t ⋅z - 24⋅t⋅x⋅y + 4⋅x ⋅z + 6⋅y ⋅z - ──
#                                         3
# Rev D* I*1 F
#                                               3
#       2                   2         2     11⋅z
# - 18⋅t ⋅z - 24⋅t⋅x⋅y + 8⋅x ⋅z + 10⋅y ⋅z + ─────
#                                             3
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# 18. Rev D*2 I*1 F*
#    2                  2        2        3
# 6⋅t ⋅z - 8⋅t⋅x⋅y - 6⋅x ⋅z - 4⋅y ⋅z - 3⋅z
# Rev D*1 I*2 F
#      2                  2      3
# - 6⋅t ⋅z - 8⋅t⋅x⋅y - 2⋅x ⋅z + z
#     2        2        2        3
# 12⋅t ⋅z - 4⋅x ⋅z - 4⋅y ⋅z - 4⋅z
# OK: 18

# %%
all_x_list = list(all_x)

for i in range(4):
    for j in range(4):
        display(all_x_list[i] + all_x_list[j])
# Out:
#     3
# 14⋅x
# ─────
#   3
#                       3
#     2                x         2        2
# 12⋅t ⋅x + 16⋅t⋅y⋅z + ── - 6⋅x⋅y  - 4⋅x⋅z
#                      3
#      2        2
# 2⋅x⋅y  + 2⋅x⋅z
#              3
#     2     2⋅x         2        2
# 12⋅t ⋅x + ──── - 4⋅x⋅y  - 4⋅x⋅z
#            3
#                       3
#     2                x         2        2
# 12⋅t ⋅x + 16⋅t⋅y⋅z + ── - 6⋅x⋅y  - 4⋅x⋅z
#                      3
#     2                   3         2        2
# 24⋅t ⋅x + 32⋅t⋅y⋅z - 4⋅x  - 12⋅x⋅y  - 8⋅x⋅z
#                          3
#     2                13⋅x         2        2
# 12⋅t ⋅x + 16⋅t⋅y⋅z - ───── - 4⋅x⋅y  - 2⋅x⋅z
#                        3
#                          3
#     2                11⋅x          2        2
# 24⋅t ⋅x + 16⋅t⋅y⋅z - ───── - 10⋅x⋅y  - 8⋅x⋅z
#                        3
#      2        2
# 2⋅x⋅y  + 2⋅x⋅z
#                          3
#     2                13⋅x         2        2
# 12⋅t ⋅x + 16⋅t⋅y⋅z - ───── - 4⋅x⋅y  - 2⋅x⋅z
#                        3
#       3
#   14⋅x         2        2
# - ───── + 4⋅x⋅y  + 4⋅x⋅z
#     3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 2⋅x⋅y  - 2⋅x⋅z
#              3
#     2     2⋅x         2        2
# 12⋅t ⋅x + ──── - 4⋅x⋅y  - 4⋅x⋅z
#            3
#                          3
#     2                11⋅x          2        2
# 24⋅t ⋅x + 16⋅t⋅y⋅z - ───── - 10⋅x⋅y  - 8⋅x⋅z
#                        3
#     2        3        2        2
# 12⋅t ⋅x - 4⋅x  - 2⋅x⋅y  - 2⋅x⋅z
#               3
#     2     10⋅x         2        2
# 24⋅t ⋅x - ───── - 8⋅x⋅y  - 8⋅x⋅z
#             3

# %%
q1 = Dq(Iq(conj(q_txyz_3, conj_type=1), [t, x, y, z], [t, x, y, z], conj=False, reverse=True), [t, x, y, z], [t, x, y, z], conj=False).expand()
q2 = Dq(Iq(conj(q_txyz_3, conj_type=1), [t, x, y, z], [t, x, y, z], conj=True, reverse=True), [t, x, y, z], [t, x, y, z], conj=True).expand()
q12 = add(q1, q2)

q1.display("q1")
q2.display("q2")
q12.display("q1 + q2")
# Out:
# q1
#    3        2        2        2
# 3⋅t  - 8⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#              3
#     2     5⋅x         2        2
# 12⋅t ⋅x - ──── - 4⋅x⋅y  - 4⋅x⋅z
#            3
#      2                   2        3        2
# - 6⋅t ⋅y - 16⋅t⋅x⋅z + 8⋅x ⋅y + 3⋅y  + 2⋅y⋅z
#      2                   2        2        3
# - 6⋅t ⋅z + 16⋅t⋅x⋅y + 8⋅x ⋅z + 2⋅y ⋅z + 3⋅z
# q2
#  3        2        2        2
# t  - 4⋅t⋅x  - 6⋅t⋅y  - 6⋅t⋅z
#               3
#     2     11⋅x          2         2
# 12⋅t ⋅x - ───── - 10⋅x⋅y  - 10⋅x⋅z
#             3
#      2                   2      3        2
# - 6⋅t ⋅y + 16⋅t⋅x⋅z + 2⋅x ⋅y + y  - 4⋅y⋅z
#      2                   2        2      3
# - 6⋅t ⋅z - 16⋅t⋅x⋅y + 2⋅x ⋅z - 4⋅y ⋅z + z
# q1 + q2
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
#               3
#     2     16⋅x          2         2
# 24⋅t ⋅x - ───── - 14⋅x⋅y  - 14⋅x⋅z
#             3
#       2         2        3        2
# - 12⋅t ⋅y + 10⋅x ⋅y + 4⋅y  - 2⋅y⋅z
#       2         2        2        3
# - 12⋅t ⋅z + 10⋅x ⋅z - 2⋅y ⋅z + 4⋅z

# %%
q1 = Dq(Iq(conj(q_txyz, conj_type=1), [t, x, y, z], [t, x, y, z], conj=False, reverse=True), [t, x, y, z], [t, x, y, z], conj=False).expand()
q2 = Dq(Iq(conj(q_txyz, conj_type=1), [t, x, y, z], [t, x, y, z], conj=True, reverse=True), [t, x, y, z], [t, x, y, z], conj=True).expand()
q12 = add(q1, q2)
q_txyz.display("q_txyz")
q12.display("q1 + q2")
# Out:
# q_txyz
# t
# x
# y
# z
# q1 + q2
# 4⋅t
# 8⋅x
# -4⋅y
# -4⋅z

# %%
q4 = product(q_txyz, q_txyz_3)
q1 = Dq(Iq(conj(q4, conj_type=1), [t, x, y, z], [t, x, y, z], conj=False, reverse=True), [t, x, y, z], [t, x, y, z], conj=False).expand()
q2 = Dq(Iq(conj(q4, conj_type=1), [t, x, y, z], [t, x, y, z], conj=True, reverse=True), [t, x, y, z], [t, x, y, z], conj=True).expand()
q12 = add(q1, q2)
q4.expand().display("q_txyz 4")
q12.display("q1 + q2")
# Out:
# q_txyz 4
#  4      2  2      2  2      2  2    4      2  2      2  2    4      2  2    4
# t  - 6⋅t ⋅x  - 6⋅t ⋅y  - 6⋅t ⋅z  + x  + 2⋅x ⋅y  + 2⋅x ⋅z  + y  + 2⋅y ⋅z  + z
#    3          3          2          2
# 4⋅t ⋅x - 4⋅t⋅x  - 4⋅t⋅x⋅y  - 4⋅t⋅x⋅z
#    3          2          3          2
# 4⋅t ⋅y - 4⋅t⋅x ⋅y - 4⋅t⋅y  - 4⋅t⋅y⋅z
#    3          2          2          3
# 4⋅t ⋅z - 4⋅t⋅x ⋅z - 4⋅t⋅y ⋅z - 4⋅t⋅z
# q1 + q2
#    4       2  2       2  2       2  2      4      2  2      2  2      4      2
# 4⋅t  - 24⋅t ⋅x  - 24⋅t ⋅y  - 24⋅t ⋅z  + 4⋅x  + 8⋅x ⋅y  + 8⋅x ⋅z  + 4⋅y  + 8⋅y
#
#   2      4
# ⋅z  + 4⋅z
#                 3                               3           3
#     3     64⋅t⋅x            2           2   16⋅y ⋅z   16⋅y⋅z
# 32⋅t ⋅x - ─────── - 56⋅t⋅x⋅y  - 56⋅t⋅x⋅z  - ─────── + ───────
#              3                                 3         3
#                                                  3           3
#       3           2           3          2   16⋅x ⋅z   16⋅x⋅z
# - 16⋅t ⋅y + 40⋅t⋅x ⋅y + 16⋅t⋅y  - 8⋅t⋅y⋅z  + ─────── - ───────
#                                                 3         3
#                                                  3           3
#       3           2          2           3   16⋅x ⋅y   16⋅x⋅y
# - 16⋅t ⋅z + 40⋅t⋅x ⋅z - 8⋅t⋅y ⋅z + 16⋅t⋅z  - ─────── + ───────
#                                                 3         3

# %%
q1 = Dq(Iq(conj(Q([t, x,0,0]), conj_type=1), [t, x, y, z], [t, x, y, z], conj=False, reverse=True), [t, x, y, z], [t, x, y, z], conj=False).expand()
q2 = Dq(Iq(conj(Q([t, x,0,0]), conj_type=1), [t, x, y, z], [t, x, y, z], conj=True, reverse=True), [t, x, y, z], [t, x, y, z], conj=True).expand()
q12 = add(q1, q2)
q12.display("q1 + q2")
# Out:
# q1 + q2
# 4⋅t
# 4⋅x
# -2⋅y
# -2⋅z

# %%
q1 = Dq(Iq(conj(square(Q([t, x,0,0])), conj_type=1), [t, x, y, z], [t, x, y, z], conj=False, reverse=True), [t, x, y, z], [t, x, y, z], conj=False).expand()
q2 = Dq(Iq(conj(square(Q([t, x,0,0])), conj_type=1), [t, x, y, z], [t, x, y, z], conj=True, reverse=True), [t, x, y, z], [t, x, y, z], conj=True).expand()
q12 = add(q1, q2)
q12.display("q1 + q2")
# Out:
# q1 + q2
#    2      2
# 4⋅t  - 4⋅x
# 8⋅t⋅x
# -4⋅t⋅y - 4⋅x⋅z
# -4⋅t⋅z + 4⋅x⋅y

# %%
q1 = Dq(Iq(q_txyz_3, [t, x, y, z], [t, x, y, z], conj=True, conj_type=1, reverse=True), [t, x, y, z], [t, x, y, z], conj=True, conj_type=2).expand()
q2 = Dq(Iq(conj(q_txyz_3, conj_type=0), [t, x, y, z], [t, x, y, z], conj=True, conj_type=1, reverse=True), [t, x, y, z], [t, x, y, z], conj=True, conj_type=2).expand()
q12 = add(q1, q2)

q1.display("q1")
q2.display("q2")
q12.display("q1 + q2")
# Out:
# q1
#  3         2        2
# t  - 10⋅t⋅y  - 6⋅t⋅z  + 8⋅x⋅y⋅z
#             3        2
# 16⋅t⋅y⋅z - x  + 4⋅x⋅y
#             3
#    2     7⋅y         2
# 6⋅t ⋅y - ──── - 2⋅y⋅z
#           3
#      2                  2      3
# - 6⋅t ⋅z + 8⋅t⋅x⋅y - 2⋅y ⋅z + z
# q2
#    3         2        2        2
# 3⋅t  - 12⋅t⋅x  - 2⋅t⋅y  - 6⋅t⋅z  - 8⋅x⋅y⋅z
#       2                  3        2        2
# - 12⋅t ⋅x + 8⋅t⋅y⋅z + 3⋅x  + 2⋅x⋅y  + 6⋅x⋅z
#                               3
#    2                   2     y         2
# 6⋅t ⋅y + 24⋅t⋅x⋅z - 6⋅x ⋅y + ── - 4⋅y⋅z
#                              3
#    2                  2        2        3
# 6⋅t ⋅z - 8⋅t⋅x⋅y - 6⋅x ⋅z - 4⋅y ⋅z - 3⋅z
# q1 + q2
#    3         2         2         2
# 4⋅t  - 12⋅t⋅x  - 12⋅t⋅y  - 12⋅t⋅z
#       2                   3        2        2
# - 12⋅t ⋅x + 24⋅t⋅y⋅z + 2⋅x  + 6⋅x⋅y  + 6⋅x⋅z
#     2                   2        3        2
# 12⋅t ⋅y + 24⋅t⋅x⋅z - 6⋅x ⋅y - 2⋅y  - 6⋅y⋅z
#      2        2        3
# - 6⋅x ⋅z - 6⋅y ⋅z - 2⋅z

# %%
ok = 0
for q1 in list(all_ID_qs):
    for q2 in list(all_ID_qs):
        q12 = q1 + q2
        
        if q12 == t**3 - 3 * t * x**2 - 3 * t * y ** 2 - 3 * t * z **2:
            print("gots it")
            print(f"q1: {q1}")
            print(f"q2: {q2}")
            print(f"q12: {q12}")
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# OK: 0

# %%
ok = 0
for q1 in list(all_ID_qs):
    for q2 in list(all_ID_qs):
        q12 = q1 + q2
        
        if q12 == 2 * t**3 - 6 * t * x**2 - 6 * t * y ** 2 - 6 * t * z **2:
            print("gots it")
            print(f"q1: {q1}")
            print(f"q2: {q2}")
            print(f"q12: {q12}")
            
            ok += 1
            
print(f"OK: {ok}")
# Out:
# OK: 0

# %%
def fundamental_t(fun, vars: List[sp.Symbol]):
    q1 = Dq(Iq(conj(square(Q([t, x,0,0]), conj_type=1), vars, vars, conj=False, reverse=True), vars, vars, conj=False).expand()
    q2 = Dq(Iq(conj(square(Q([t, x,0,0])), conj_type=1), vars, vars, conj=True, reverse=True), vars, vars, conj=True).expand()
    q12 = add(q1, q2)
